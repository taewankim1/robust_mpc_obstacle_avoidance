# %%
import matplotlib.pyplot as plt
# %matplotlib inline  
# %load_ext autoreload
# %autoreload 2
import numpy as np
import time
import random
def print_np(x):
    print ("Type is %s" % (type(x)))
    print ("Shape is %s" % (x.shape,))
#     print ("Values are: \n%s" % (x))

# %%
import os
import sys
sys.path.append('../')

# %%
from model import UnicycleModel
from cost import FinaltimeFreeCost, UnicycleCost
from constraints import UnicycleConstraints
from PTR_tf_free import PTR_tf_free
from PTR_in_MPC import PTR_in_MPC
from Scaling import TrajectoryScaling

from scipy.interpolate import interp1d
from scipy.integrate import solve_ivp
# Out:
# (CVXPY) Dec 10 12:44:29 AM: Encountered unexpected exception importing solver SCS:
# ImportError("dlopen(/opt/anaconda3/envs/py309/lib/python3.9/site-packages/_scs_direct.cpython-39-darwin.so, 0x0002): Library not loaded: @rpath/liblapack.3.dylib\n  Referenced from: /opt/anaconda3/envs/py309/lib/python3.9/site-packages/_scs_direct.cpython-39-darwin.so\n  Reason: tried: '/opt/anaconda3/envs/py309/lib/python3.9/site-packages/../../liblapack.3.dylib' (no such file), '/opt/anaconda3/envs/py309/lib/python3.9/site-packages/../../liblapack.3.dylib' (no such file), '/opt/anaconda3/envs/py309/bin/../lib/liblapack.3.dylib' (no such file), '/opt/anaconda3/envs/py309/bin/../lib/liblapack.3.dylib' (no such file), '/usr/local/lib/liblapack.3.dylib' (no such file), '/usr/lib/liblapack.3.dylib' (no such file)")

# %% [markdown]
# ## Nominal trajectory generation

# %%
ix = 3
iu = 2
ih = 2
N = 50
tf = 10
delT = tf/N
max_iter = 30

# %%
myModel = UnicycleModel.unicycle('Hello',ix,iu,'numeric_central')
myCost = FinaltimeFreeCost.Finaltime('Hello',ix,iu,N)
myConst = UnicycleConstraints.UnicycleConstraints('Hello',ix,iu,[],[])

# %%
xi = np.zeros(3)
xi[0] = -5.0
xi[1] = -5.0 
xi[2] = 0

xf = np.zeros(3)
xf[0] = 5.0
xf[1] = 5.0
xf[2] = 0

x0 = np.zeros((N+1,ix))
for i in range(N+1) :
    x0[i] = (N-i)/N * xi + i/N * xf
    
u0 = np.zeros((N+1,iu))
ui = np.array([2,0])
uf = np.array([2,0])
for i in range(N+1) :
    u0[i] = (N-i)/N * ui + i/N * uf
    
x_max = np.array([5,5,np.deg2rad(90)])
x_min = np.zeros(ix)

u_max = np.array([2,np.deg2rad(90)]) 
u_min = np.array([0,0])


myScaling = TrajectoryScaling(x_min,x_max,u_min,u_max,tf)
Sx,iSx,sx,Su,iSu,su = myScaling.get_scaling()


TrajOpt = PTR_tf_free('unicycle',N,tf,max_iter,myModel,myCost,myConst,myScaling,
          type_discretization="foh",w_tf=1,w_vc=1e3,w_tr=1e-1,tol_vc=1e-6,tol_tr=1e-3)
# Out:
# Is DPP?  True

# %%
xfwd,ufwd,xnom,unom,tfnom,total_num_iter,l_all,l_tf,l_vc,l_tr,history_nom  = TrajOpt.run(x0,u0,xi,xf)
print("final time {:}".format(tfnom))
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2023-11-07
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │5.696      │5.000     │0        │0          │0           │1(-14.10)│0(6.958 )│0(0.128 )│
# │2     │7.734      │6.976     │0        │0          │0.597       │1(-14.06)│0(7.573 )│0(0.065 )│
# │3     │7.324      │7.132     │0        │0          │0.869       │1(-14.06)│0(1.919 )│0(0.015 )│
# │4     │7.256      │7.253     │0        │0          │0.983       │1(-14.23)│0(0.030 )│1(0.000 )│
# │5     │7.252      │7.251     │0        │0          │0.928       │1(-14.26)│0(0.010 )│1(0.000 )│
# │6     │7.251      │7.250     │0        │0          │0.473       │1(-14.30)│0(0.006 )│1(0.000 )│
# │7     │7.250      │7.250     │0        │0          │0.647       │1(-14.21)│0(0.002 )│1(0.000 )│
# │8     │7.250      │7.250     │0        │0          │0.596       │1(-14.21)│0(0.001 )│1(0.000 )│
# │9     │7.250      │7.250     │0        │0          │0.443       │1(-14.27)│1(0.001 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# final time 7.249560285243445

# %%
t_nom = np.array([i for i in range(N+1)]) / N * tfnom

# %%
plt.figure(figsize=(15,10))
fS = 18
plt.subplot(231)
plt.plot(xnom[:,0], xnom[:,1],'-', linewidth=2.0)
plt.plot(xf[0],xf[1],"o",label='goal')
plt.gca().set_aspect('equal', adjustable='box')
plt.axis([-6, 6, -6, 6])
plt.xlabel('X (m)', fontsize = fS)
plt.ylabel('Y (m)', fontsize = fS)
plt.subplot(232)
plt.plot(t_nom, xnom[:,0],'-', linewidth=2.0)
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('x (m)', fontsize = fS)
plt.subplot(233)
plt.plot(t_nom, xnom[:,1],'-',linewidth=2.0)
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('y (m)', fontsize = fS)
plt.subplot(234)
plt.plot(t_nom, np.rad2deg(xnom[:,2]),'-',linewidth=2.0)
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('$\Theta$ (deg)', fontsize = fS)
plt.subplot(235)
plt.plot(t_nom, unom[:,0],'-',linewidth=2.0)
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('v (m/s)', fontsize = fS)
plt.ylim([0,3])
plt.subplot(236)
plt.plot(t_nom, np.rad2deg(unom[:,1]),'-',linewidth=2.0)
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('w (deg/s)', fontsize = fS)
plt.show()

# %% [markdown]
# ## Set MPC controller with static obstacle

# %% [markdown]
# ### nominal trajectory is given as xbar, ubar

# %%
fun_unom = interp1d(t_nom,unom,axis=0)
def get_traj_teval(t_eval) :
    if len(t_eval) == 0 :
        return [],[]
    assert np.max(t_eval) <= t_nom[-1]
    def dfdt(t,x) :
        u = fun_unom(t)
        return np.squeeze(myModel.forward(x,u))

    sol = solve_ivp(dfdt,(t_nom[0],t_nom[-1]),xi,t_eval=t_eval,rtol=1e-12,atol=1e-12)
    return sol.y.T,fun_unom(t_eval)

def forward_dt(dt,xi,u) :
    def dfdt(t,x) :
        return np.squeeze(myModel.forward(x,u))
    sol = solve_ivp(dfdt,(0,dt),xi,rtol=1e-12,atol=1e-12)
    return sol
def get_H_obs(rx,ry) :
    return np.diag([1/rx,1/ry])

# %%
tbar = np.array([i for i in range(N+1)]) / N * tfnom
tfsim = 8
horizon = 2
dt = 0.1
Nsim = int(tfsim / dt)
Nmpc =  int(horizon / dt) # N+1 is total discretization points for state
print("Nmpc: {:}".format(Nmpc))

xi_mpc = np.zeros(3)
xi_mpc[0] = -5.0
xi_mpc[1] = -4.0 
xi_mpc[2] = 0
# Out:
# Nmpc: 20

# %%
# cost and constraint / model is identical
MPC_Cost = UnicycleCost.UnicycleMPCCost('Hello',ix,iu,Nmpc)
MPC_Const = UnicycleConstraints.UnicycleMPCConstraints('Hello',ix,iu,num_obs=1)

# # define optimal control
MPC_controller = PTR_in_MPC('unicycle',Nmpc,horizon,max_iter,myModel,MPC_Cost,MPC_Const,myScaling,
          type_discretization="zoh",w_c=1,w_vc=1e3,w_tr=1e0,
                            tol_vc=1e-6,tol_tr=1e-3,verbosity=False)
# Out:
# Is DPP?  True

# %%
t_curr = 0
x_curr = np.copy(xi_mpc)

t_save,x_save,u_save = [],[],[]
t_save.append(t_curr)
x_save.append(xi_mpc)

t_traj,x_traj,u_traj = [],[],[]
c_traj,H_traj = [],[]


for _ in range(Nsim) : # Nsim
    print("t curr: {:.2f}  ======================".format(t_curr))
    # estimating nominal trajectory within horizon
    t_horizon = np.array([t_curr + dt*i for i in range(Nmpc+1)])
    t_eval = t_horizon[t_horizon <= tfnom]
    t_end = t_horizon[t_horizon > tfnom]
    xfwd,ufwd = get_traj_teval(t_eval)
    for _ in t_end :
        if len(xfwd) == 0 :
            xfwd = xnom[-1]
            ufwd = unom[-1]
        else :
            xfwd = np.vstack((xfwd,xnom[-1]))
            ufwd = np.vstack((ufwd,unom[-1]))


    # estimate the model of non-cooperative agent
    cobs,Hobs = [],[]
    # static obstacle
    c = [0,1]
    H = get_H_obs(2,2)
    for i in range(Nmpc+1) :
        cobs.append(c)
        Hobs.append(H)
        
    
    # solve optimal control
    # initiall condition
    if t_curr == 0 :
        x0 = xfwd
        u0 = ufwd
    else :
        x0 = np.copy(xmpc)
        x0[:Nmpc] = xmpc[1:]
        u0 = np.copy(umpc)
        u0[:Nmpc] = umpc[1:]


    _,_,xmpc,umpc,tfmpc,_,l_all,l_c,l_vc,l_tr,history_mpc  = MPC_controller.run(x0,u0,x_curr,xfwd,ufwd,cobs,Hobs)

    # apply input to the system (integration)
    sol = forward_dt(dt,x_curr,umpc[0])
    t_curr += dt
    x_curr = sol.y.T[-1]

    # save
    t_save.append(t_curr)
    x_save.append(x_curr)
    u_save.append(umpc[0])

    t_traj.append(t_horizon)
    x_traj.append(xmpc)
    u_traj.append(umpc)
#     break

x_save = np.array(x_save)
u_save = np.array(u_save)
# Out:
# t curr: 0.00  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │129.550    │2.000     │124      │0          │0           │1(-13.97)│0(5.188 )│0(0.029 )│
# │2     │134.723    │2.000     │134      │0          │0.986       │1(-13.98)│0(0.299 )│1(0.001 )│
# │3     │133.959    │2.000     │134      │0          │0.822       │1(-11.80)│0(0.038 )│1(0.000 )│
# │4     │133.891    │2.000     │134      │0          │0.951       │1(-11.84)│0(0.003 )│1(0.000 )│
# │5     │133.885    │2.000     │134      │0          │0.903       │1(-11.33)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 0.10  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │122.557    │2.000     │122      │0          │0           │1(-11.19)│0(0.113 )│1(0.000 )│
# │2     │122.430    │2.000     │122      │0          │0.937       │1(-11.49)│0(0.002 )│1(0.000 )│
# │3     │122.427    │2.000     │122      │0          │0.993       │1(-11.49)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 0.20  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │111.142    │2.000     │111      │0          │0           │1(-11.32)│0(0.115 )│1(0.000 )│
# │2     │111.012    │2.000     │111      │0          │0.936       │1(-11.27)│0(0.002 )│1(0.000 )│
# │3     │111.010    │2.000     │111      │0          │0.993       │1(-11.26)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 0.30  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │100.604    │2.000     │100      │0          │0           │1(-11.13)│0(0.116 )│1(0.000 )│
# │2     │100.473    │2.000     │100      │0          │0.936       │1(-11.13)│0(0.002 )│1(0.000 )│
# │3     │100.470    │2.000     │100      │0          │0.994       │1(-11.13)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 0.40  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │91.527     │2.000     │91.4     │0          │0           │1(-11.40)│0(0.117 )│1(0.000 )│
# │2     │91.395     │2.000     │91.4     │0          │0.938       │1(-11.48)│0(0.002 )│1(0.000 )│
# │3     │91.392     │2.000     │91.4     │0          │0.994       │1(-11.46)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 0.50  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │84.337     │2.000     │84.2     │0          │0           │1(-11.15)│0(0.117 )│1(0.000 )│
# │2     │84.204     │2.000     │84.2     │0          │0.941       │1(-10.83)│0(0.002 )│1(0.000 )│
# │3     │84.201     │2.000     │84.2     │0          │0.993       │1(-10.82)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 0.60  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │78.728     │2.000     │78.6     │0          │0           │1(-11.35)│0(0.118 )│1(0.000 )│
# │2     │78.595     │2.000     │78.6     │0          │0.944       │1(-11.23)│0(0.002 )│1(0.000 )│
# │3     │78.592     │2.000     │78.6     │0          │0.993       │1(-11.22)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 0.70  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │74.379     │2.000     │74.3     │0          │0           │1(-10.96)│0(0.118 )│1(0.000 )│
# │2     │74.245     │2.000     │74.2     │0          │0.948       │1(-10.95)│0(0.002 )│1(0.000 )│
# │3     │74.242     │2.000     │74.2     │0          │0.992       │1(-10.95)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 0.80  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │71.215     │2.000     │71.1     │0          │0           │1(-11.05)│0(0.118 )│1(0.000 )│
# │2     │71.081     │2.000     │71.1     │0          │0.953       │1(-11.04)│0(0.002 )│1(0.000 )│
# │3     │71.078     │2.000     │71.1     │0          │0.992       │1(-11.04)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 0.90  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │69.207     │2.000     │69.1     │0          │0           │1(-11.04)│0(0.119 )│1(0.000 )│
# │2     │69.073     │2.000     │69.1     │0          │0.957       │1(-11.03)│0(0.002 )│1(0.000 )│
# │3     │69.070     │2.000     │69.1     │0          │0.993       │1(-11.03)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 1.00  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │68.092     │2.000     │68       │0          │0           │1(-10.92)│0(0.119 )│1(0.000 )│
# │2     │67.958     │2.000     │68       │0          │0.962       │1(-10.91)│0(0.002 )│1(0.000 )│
# │3     │67.955     │2.000     │68       │0          │0.992       │1(-10.91)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 1.10  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │67.596     │2.000     │67.5     │0          │0           │1(-10.91)│0(0.119 )│1(0.000 )│
# │2     │67.462     │2.000     │67.5     │0          │0.966       │1(-10.90)│0(0.002 )│1(0.000 )│
# │3     │67.459     │2.000     │67.5     │0          │0.992       │1(-10.90)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 1.20  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │67.493     │2.000     │67.4     │0          │0           │1(-10.91)│0(0.119 )│1(0.000 )│
# │2     │67.358     │2.000     │67.4     │0          │0.969       │1(-10.90)│0(0.002 )│1(0.000 )│
# │3     │67.355     │2.000     │67.4     │0          │0.991       │1(-10.90)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 1.30  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │67.611     │2.000     │67.5     │0          │0           │1(-10.92)│0(0.119 )│1(0.000 )│
# │2     │67.476     │2.000     │67.5     │0          │0.972       │1(-10.90)│0(0.002 )│1(0.000 )│
# │3     │67.473     │2.000     │67.5     │0          │0.991       │1(-10.90)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 1.40  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │68.363     │2.000     │68.3     │0          │0           │1(-10.93)│0(0.018 )│1(0.000 )│
# │2     │68.341     │2.000     │68.3     │0          │0.99        │1(-10.91)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 1.50  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │72.099     │2.000     │72.1     │0          │0           │1(-10.95)│0(0.002 )│1(0.000 )│
# │2     │72.096     │2.000     │72.1     │0          │0.996       │1(-10.63)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 1.60  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │79.539     │2.000     │79.5     │0          │0           │1(-10.88)│0(0.003 )│1(0.000 )│
# │2     │79.530     │2.000     │79.5     │0          │0.985       │1(-10.39)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 1.70  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │91.340     │2.000     │91.3     │0          │0           │1(-10.80)│0(0.004 )│1(0.000 )│
# │2     │91.320     │2.000     │91.3     │0          │0.966       │1(-10.55)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 1.80  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │108.169    │2.000     │108      │0          │0           │1(-10.01)│0(0.005 )│1(0.000 )│
# │2     │108.133    │2.000     │108      │0          │0.941       │1(-10.64)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 1.90  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │130.672    │2.000     │131      │0          │0           │1(-10.17)│0(0.007 )│1(0.000 )│
# │2     │130.609    │2.000     │131      │0          │0.908       │1(-10.45)│1(0.001 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 2.00  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │159.450    │2.000     │159      │0          │0           │1(-10.94)│0(0.009 )│1(0.000 )│
# │2     │159.344    │2.000     │159      │0          │0.867       │1(-11.34)│0(0.001 )│1(0.000 )│
# │3     │159.331    │2.000     │159      │0          │0.857       │1(-11.39)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 2.10  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │195.016    │2.000     │195      │0          │0           │1(-10.60)│0(0.011 )│1(0.000 )│
# │2     │194.861    │2.000     │195      │0          │0.814       │1(-11.29)│0(0.002 )│1(0.000 )│
# │3     │194.832    │2.000     │195      │0          │0.802       │1(-11.37)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 2.20  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │237.803    │2.000     │238      │0          │0           │1(-10.75)│0(0.015 )│1(0.000 )│
# │2     │237.545    │2.000     │238      │0          │0.742       │1(-10.72)│0(0.004 )│1(0.000 )│
# │3     │237.474    │2.000     │237      │0          │0.718       │1(-11.37)│0(0.001 )│1(0.000 )│
# │4     │237.451    │2.000     │237      │0          │0.704       │1(-11.37)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 2.30  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │287.897    │2.000     │288      │0          │0           │1(-11.41)│0(0.020 )│1(0.000 )│
# │2     │287.469    │2.000     │287      │0          │0.642       │1(-10.76)│0(0.008 )│1(0.000 )│
# │3     │287.292    │2.000     │287      │0          │0.611       │1(-11.26)│0(0.004 )│1(0.000 )│
# │4     │287.210    │2.000     │287      │0          │0.591       │1(-11.29)│0(0.002 )│1(0.000 )│
# │5     │287.170    │2.000     │287      │0          │0.581       │1(-11.31)│0(0.001 )│1(0.000 )│
# │6     │287.150    │2.000     │287      │0          │0.571       │1(-11.39)│1(0.001 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 2.40  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │344.622    │2.000     │345      │0          │0           │1(-11.71)│0(0.027 )│1(0.000 )│
# │2     │343.849    │2.000     │344      │0          │0.522       │1(-10.64)│0(0.016 )│1(0.000 )│
# │3     │343.370    │2.000     │343      │0          │0.486       │1(-11.18)│0(0.012 )│1(0.000 )│
# │4     │343.041    │2.000     │343      │0          │0.465       │1(-11.20)│0(0.009 )│1(0.000 )│
# │5     │342.800    │2.000     │343      │0          │0.414       │1(-11.10)│0(0.007 )│1(0.000 )│
# │6     │342.604    │2.000     │343      │0          │0.361       │1(-10.98)│0(0.006 )│1(0.000 )│
# │7     │342.430    │2.000     │342      │0          │0.334       │1(-11.18)│0(0.006 )│1(0.000 )│
# │8     │342.270    │2.000     │342      │0          │0.319       │1(-11.27)│0(0.006 )│1(0.000 )│
# │9     │342.118    │2.000     │342      │0          │0.31        │1(-11.29)│0(0.006 )│1(0.000 )│
# │10    │341.968    │2.000     │342      │0          │0.304       │1(-11.28)│0(0.006 )│1(0.000 )│
# │11    │341.819    │2.000     │342      │0          │0.3         │1(-11.27)│0(0.006 )│1(0.000 )│
# │12    │341.668    │2.000     │342      │0          │0.299       │1(-11.26)│0(0.006 )│1(0.000 )│
# │13    │341.513    │2.000     │342      │0          │0.3         │1(-11.25)│0(0.006 )│1(0.000 )│
# │14    │341.352    │2.000     │341      │0          │0.304       │1(-11.19)│0(0.006 )│1(0.000 )│
# │15    │341.185    │2.000     │341      │0          │0.309       │1(-11.14)│0(0.007 )│1(0.000 )│
# │16    │341.010    │2.000     │341      │0          │0.291       │1(-11.44)│0(0.007 )│1(0.000 )│
# │17    │340.814    │2.000     │341      │0          │0.178       │1(-11.29)│0(0.008 )│1(0.000 )│
# │18    │340.564    │2.000     │341      │0          │0.133       │1(-11.35)│0(0.010 )│1(0.000 )│
# │19    │340.236    │2.000     │340      │0          │0.144       │1(-11.43)│0(0.014 )│1(0.000 )│
# │20    │339.799    │2.000     │340      │0          │0.157       │1(-11.32)│0(0.019 )│1(0.000 )│
# │21    │339.219    │2.000     │339      │0          │0.185       │1(-11.20)│0(0.026 )│1(0.000 )│
# │22    │338.462    │2.000     │338      │0          │0.224       │1(-11.27)│0(0.034 )│1(0.001 )│
# │23    │337.466    │2.000     │337      │0          │0.126       │1(-10.89)│0(0.044 )│1(0.001 )│
# │24    │335.951    │2.000     │336      │0          │0.0585      │1(-10.69)│0(0.071 )│0(0.001 )│
# │25    │333.595    │2.000     │333      │0          │0.144       │1(-10.93)│0(0.114 )│0(0.002 )│
# │26    │330.006    │2.000     │330      │0          │0.0605      │1(-10.83)│0(0.175 )│0(0.002 )│
# │27    │323.908    │2.000     │324      │0          │0.0533      │1(-10.70)│0(0.306 )│0(0.004 )│
# │28    │314.589    │2.000     │314      │0          │0.787       │1(-10.88)│0(0.536 )│0(0.001 )│
# │29    │305.958    │2.000     │305      │0          │0.602       │1(-10.83)│0(0.569 )│0(0.001 )│
# │30    │300.995    │2.000     │301      │0          │-0.7        │1(-11.36)│0(0.303 )│0(0.005 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                NOT ENOUGH : reached to max iteration                                         │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 2.50  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │323.231    │2.000     │323      │0          │0           │1(-11.11)│0(0.334 )│0(0.004 )│
# │2     │321.213    │2.000     │321      │0          │0.818       │1(-11.44)│0(0.051 )│1(0.001 )│
# │3     │320.775    │2.000     │321      │0          │0.833       │1(-10.37)│0(0.009 )│1(0.000 )│
# │4     │320.666    │2.000     │321      │0          │0.84        │1(-10.79)│0(0.002 )│1(0.000 )│
# │5     │320.633    │2.000     │321      │0          │0.814       │1(-10.98)│1(0.001 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 2.60  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │339.840    │2.000     │340      │0          │0           │1(-11.37)│0(0.208 )│0(0.002 )│
# │2     │338.842    │2.000     │339      │0          │0.83        │1(-10.94)│0(0.030 )│1(0.000 )│
# │3     │338.645    │2.000     │339      │0          │0.822       │1(-11.00)│0(0.006 )│1(0.000 )│
# │4     │338.600    │2.000     │339      │0          │0.828       │1(-11.01)│0(0.001 )│1(0.000 )│
# │5     │338.589    │2.000     │339      │0          │0.815       │1(-11.01)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 2.70  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │354.384    │2.000     │354      │0          │0           │1(-10.89)│0(0.212 )│0(0.001 )│
# │2     │353.602    │2.000     │354      │0          │0.83        │1(-11.02)│0(0.024 )│1(0.000 )│
# │3     │353.459    │2.000     │353      │0          │0.831       │1(-11.01)│0(0.004 )│1(0.000 )│
# │4     │353.428    │2.000     │353      │0          │0.843       │1(-11.00)│1(0.001 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 2.80  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │365.887    │2.000     │366      │0          │0           │1(-11.14)│0(0.204 )│1(0.001 )│
# │2     │365.157    │2.000     │365      │0          │0.754       │1(-11.01)│0(0.026 )│1(0.000 )│
# │3     │365.026    │2.000     │365      │0          │0.843       │1(-11.03)│0(0.004 )│1(0.000 )│
# │4     │365.002    │2.000     │365      │0          │0.851       │1(-11.03)│1(0.001 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 2.90  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │373.806    │2.000     │374      │0          │0           │1(-10.61)│0(0.196 )│1(0.001 )│
# │2     │373.192    │2.000     │373      │0          │0.817       │1(-10.98)│0(0.018 )│1(0.000 )│
# │3     │373.105    │2.000     │373      │0          │0.864       │1(-11.02)│0(0.002 )│1(0.000 )│
# │4     │373.091    │2.000     │373      │0          │0.867       │1(-11.01)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 3.00  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │378.337    │2.000     │378      │0          │0           │1(-10.54)│0(0.171 )│1(0.001 )│
# │2     │377.872    │2.000     │378      │0          │0.774       │1(-11.02)│0(0.017 )│1(0.000 )│
# │3     │377.811    │2.000     │378      │0          │0.889       │1(-10.98)│0(0.002 )│1(0.000 )│
# │4     │377.802    │2.000     │378      │0          │0.866       │1(-11.09)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 3.10  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │379.453    │2.000     │379      │0          │0           │1(-10.90)│0(0.160 )│1(0.001 )│
# │2     │379.065    │2.000     │379      │0          │0.797       │1(-11.16)│0(0.013 )│1(0.000 )│
# │3     │379.021    │2.000     │379      │0          │0.919       │1(-11.00)│0(0.001 )│1(0.000 )│
# │4     │379.015    │2.000     │379      │0          │0.864       │1(-11.02)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 3.20  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │376.801    │2.000     │377      │0          │0           │1(-10.80)│0(0.145 )│1(0.001 )│
# │2     │376.495    │2.000     │376      │0          │0.86        │1(-11.07)│0(0.008 )│1(0.000 )│
# │3     │376.470    │2.000     │376      │0          │0.934       │1(-11.29)│1(0.001 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 3.30  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │370.072    │2.000     │370      │0          │0           │1(-10.92)│0(0.130 )│1(0.001 )│
# │2     │369.837    │2.000     │370      │0          │0.859       │1(-11.93)│0(0.007 )│1(0.000 )│
# │3     │369.819    │2.000     │370      │0          │0.945       │1(-11.42)│1(0.001 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 3.40  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │358.675    │2.000     │359      │0          │0           │1(-11.38)│0(0.121 )│1(0.001 )│
# │2     │358.481    │2.000     │358      │0          │0.873       │1(-11.30)│0(0.006 )│1(0.000 )│
# │3     │358.467    │2.000     │358      │0          │0.954       │1(-11.39)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 3.50  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │342.721    │2.000     │343      │0          │0           │1(-10.90)│0(0.115 )│1(0.001 )│
# │2     │342.553    │2.000     │343      │0          │0.89        │1(-10.90)│0(0.004 )│1(0.000 )│
# │3     │342.544    │2.000     │343      │0          │0.971       │1(-10.90)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 3.60  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │323.766    │2.000     │324      │0          │0           │1(-11.10)│0(0.110 )│1(0.001 )│
# │2     │323.618    │2.000     │324      │0          │0.903       │1(-11.10)│0(0.003 )│1(0.000 )│
# │3     │323.612    │2.000     │324      │0          │0.98        │1(-11.11)│1(0.000 )│1(0.000 )│
# ...
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │33.192     │2.000     │33.2     │0          │0           │1(-11.15)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 6.50  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │29.260     │2.000     │29.3     │0          │0           │1(-11.40)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 6.60  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │25.329     │2.000     │25.3     │0          │0           │1(-11.51)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 6.70  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │21.455     │2.000     │21.5     │0          │0           │1(-11.49)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 6.80  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │17.713     │2.000     │17.7     │0          │0           │1(-11.64)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 6.90  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │14.191     │2.000     │14.2     │0          │0           │1(-11.51)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 7.00  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │10.979     │2.000     │11       │0          │0           │1(-11.36)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 7.10  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │8.157      │2.000     │8.16     │0          │0           │1(-11.11)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 7.20  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │5.759      │2.000     │5.76     │0          │0           │1(-12.00)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 7.30  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │3.694      │2.000     │3.69     │0          │0           │1(-11.59)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 7.40  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │2.193      │2.000     │2.19     │0          │0           │1(-12.43)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 7.50  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │1.394      │2.000     │1.39     │0          │0           │1(-12.54)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 7.60  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │0.969      │2.000     │0.969    │0          │0           │1(-12.26)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 7.70  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │0.743      │2.000     │0.743    │0          │0           │1(-12.10)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 7.80  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │0.623      │2.000     │0.623    │0          │0           │1(-11.89)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 7.90  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │0.559      │2.000     │0.559    │0          │0           │1(-11.65)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
plt.figure(figsize=(15,10))
fS = 18
plt.subplot(231)
plt.plot(xnom[:,0], xnom[:,1],'--', linewidth=2.0)
plt.plot(x_save[:,0], x_save[:,1],'-', linewidth=2.0)
plt.plot(xf[0],xf[1],"o",label='goal')
plt.gca().set_aspect('equal', adjustable='box')
plt.axis([-6, 6, -6, 6])
plt.xlabel('X (m)', fontsize = fS)
plt.ylabel('Y (m)', fontsize = fS)
plt.subplot(232)
plt.plot(t_nom, xnom[:,0],'--', linewidth=2.0)
plt.plot(t_save, x_save[:,0],'-',linewidth=2.0)
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('x1 (m)', fontsize = fS)
plt.subplot(233)
plt.plot(t_nom, xnom[:,1],'--',linewidth=2.0)
plt.plot(t_save, x_save[:,1],'-',linewidth=2.0)
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('x2 (m)', fontsize = fS)
plt.subplot(234)
plt.plot(t_nom, np.rad2deg(xnom[:,2]),'--',linewidth=2.0)
plt.plot(t_save, np.rad2deg(x_save[:,2]),'-',linewidth=2.0)
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('x3 (rad)', fontsize = fS)
plt.subplot(235)
plt.plot(t_nom, unom[:,0],'--',linewidth=2.0)
plt.step(t_save,[*u_save[:,0],u_save[-1,0]],label='zoh',where='post')
plt.plot(t_save, np.array(t_save)*0+MPC_Const.vmax,'--',linewidth=2.0,color='tab:red')
plt.plot(t_save, np.array(t_save)*0+MPC_Const.vmin,'--',linewidth=2.0,color='tab:red')
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('v (m/s)', fontsize = fS)
plt.subplot(236)
plt.plot(t_nom, np.rad2deg(unom[:,1]),'--',linewidth=2.0)
plt.step(t_save,np.rad2deg([*u_save[:,1],u_save[-1,1]]),label='zoh',where='post')
plt.plot(t_save, np.array(t_save)*0+np.rad2deg(MPC_Const.wmax),'--',linewidth=2.0,color='tab:red')
plt.plot(t_save, np.array(t_save)*0+np.rad2deg(MPC_Const.wmin),'--',linewidth=2.0,color='tab:red')
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('w (rad/s)', fontsize = fS)
plt.show()

# %% [markdown]
# ## make a video

# %%
from matplotlib.patches import Rectangle,Ellipse
import imageio
import os

# %%
filenames = []
for idx in range(Nsim+1) :
    fig = plt.figure(figsize=(10,10))
    ax = fig.add_subplot(111)
    fS = 15
    plt.plot(xnom[:,0], xnom[:,1],'--', linewidth=2.0,label='nominal trajectory')
    plt.plot(x_save[:idx+1,0], x_save[:idx+1,1],'-', linewidth=2.0,label='result trajectory')
    if idx < Nsim :
        plt.plot(x_traj[idx][:,0], x_traj[idx][:,1],'-',color='tab:green', linewidth=2.0,label='future prediction')
        plt.plot(x_traj[idx][0,0], x_traj[idx][0,1],'o',color='tab:green', linewidth=2.0)
    for ce,H in zip(cobs,Hobs) :
        rx = 1/H[0,0]
        ry = 1/H[1,1]
        circle1 = Ellipse((ce[0],ce[1]),rx*2,ry*2,color='tab:red',alpha=0.03,fill=True)
        ax.add_patch(circle1)
    plt.gca().set_aspect('equal', adjustable='box')
    plt.axis([-6, 6, -6, 6])
    plt.xlabel('X (m)', fontsize = fS)
    plt.ylabel('Y (m)', fontsize = fS)
    plt.legend(fontsize=fS)

    filename = '../images/{:d}.png'.format(idx)
    plt.savefig(filename)
    filenames.append(filename)
    plt.close()

# %%
img_name = 'MPC_static_obstacle'
with imageio.get_writer('../images/'+img_name+'.gif', mode='I') as writer:
        for filename in filenames:
            image = imageio.imread(filename)
            writer.append_data(image)
for filename in set(filenames):
    os.remove(filename)
