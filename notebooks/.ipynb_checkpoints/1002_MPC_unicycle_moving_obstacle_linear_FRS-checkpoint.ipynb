# %%
import matplotlib.pyplot as plt
# %matplotlib inline  
# %load_ext autoreload
# %autoreload 2
import numpy as np
import scipy as sp
import time
import random
def print_np(x):
    print ("Type is %s" % (type(x)))
    print ("Shape is %s" % (x.shape,))
#     print ("Values are: \n%s" % (x))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
# sys.path.append('../')
sys.path.append('../')
sys.path.append('../model')
sys.path.append('../cost')
sys.path.append('../constraints')
import UnicycleModel
import FinaltimeFreeCost
import UnicycleCost
import UnicycleConstraints
from scipy.integrate import solve_ivp
from PTR_tf_free import PTR_tf_free
from PTR_in_MPC import PTR_in_MPC
from Scaling import TrajectoryScaling
from scipy.interpolate import interp1d
from scipy.integrate import solve_ivp
# Out:
# (CVXPY) Oct 02 08:30:25 PM: Encountered unexpected exception importing solver SCS:
# ImportError("dlopen(/opt/anaconda3/envs/py309/lib/python3.9/site-packages/_scs_direct.cpython-39-darwin.so, 0x0002): Library not loaded: @rpath/liblapack.3.dylib\n  Referenced from: /opt/anaconda3/envs/py309/lib/python3.9/site-packages/_scs_direct.cpython-39-darwin.so\n  Reason: tried: '/opt/anaconda3/envs/py309/lib/python3.9/site-packages/../../liblapack.3.dylib' (no such file), '/opt/anaconda3/envs/py309/lib/python3.9/site-packages/../../liblapack.3.dylib' (no such file), '/opt/anaconda3/envs/py309/bin/../lib/liblapack.3.dylib' (no such file), '/opt/anaconda3/envs/py309/bin/../lib/liblapack.3.dylib' (no such file), '/usr/local/lib/liblapack.3.dylib' (no such file), '/usr/lib/liblapack.3.dylib' (no such file)")

# %%
import seaborn as sns
sns.set()

# %% [markdown]
# ## Nominal trajectory generation

# %%
ix = 3
iu = 2
ih = 2
N = 50
tf = 10
delT = tf/N
max_iter = 30

# %%
x_max = np.array([5,5,np.deg2rad(90)])
x_min = np.zeros(ix)

u_max = np.array([2,np.deg2rad(90)]) 
u_min = np.array([0,0])

myScaling = TrajectoryScaling(x_min,x_max,u_min,u_max,tf)
Sx,iSx,sx,Su,iSu,su = myScaling.get_scaling()

# %%
myModel = UnicycleModel.unicycle('Hello',ix,iu,'numeric_central')
myCost = FinaltimeFreeCost.Finaltime('Hello',ix,iu,N)
myConst = UnicycleConstraints.UnicycleConstraints('Hello',ix,iu)

# %%
xi = np.zeros(3)
xi[0] = -5.0
xi[1] = -5.0 
xi[2] = 0

xf = np.zeros(3)
xf[0] = 5.0
xf[1] = 5.0
xf[2] = 0


x0 = np.zeros((N+1,ix))
for i in range(N+1) :
    x0[i] = (N-i)/N * xi + i/N * xf
    
u0 = np.zeros((N+1,iu))
ui = np.array([2,0])
uf = np.array([2,0])

for i in range(N+1) :
    u0[i] = (N-i)/N * ui + i/N * uf

# %%
TrajOpt = PTR_tf_free('unicycle',N,tf,max_iter,myModel,myCost,myConst,myScaling,
          type_discretization="foh",w_c=1,w_vc=1e3,w_tr=1e-1,w_rate=0,tol_vc=1e-6,tol_tr=1e-3)
xfwd,ufwd,xbar,ubar,tfbar,total_num_iter,flag_boundary,l,l_vc,l_tr,x_traj,u_traj,T_traj  = TrajOpt.run(x0,u0,xi,xf)
print("final time {:}".format(tfbar))
# Out:
# iteration   total_cost        cost        ||vc||     ||tr||       reduction   w_tr        dynamics
# 1           5.696             5.000       1.95e-12    6.96        4.3         0.100       0(0.128)
# 2           7.734             6.976       3.95e-12    7.57        -2.04       0.100       0(0.0652)
# 3           7.324             7.132       3.9e-13     1.92        0.409       0.100       0(0.0153)
# 4           7.256             7.253       1.06e-11    0.0302      0.0685      0.100       1(0.000274)
# 5           7.252             7.251       8.5e-12     0.0098      0.00348     0.100       1(2.3e-05)
# 6           7.251             7.250       1.46e-12    0.00635     0.00153     0.100       1(1.8e-05)
# 7           7.250             7.250       1.01e-12    0.00157     0.000715    0.100       1(3.7e-06)
# 8           7.250             7.250       8.91e-13    0.00109     0.000236    0.100       1(1.6e-06)
# 9           7.250             7.250       7.81e-13    0.000881    0.000185    0.100       1(1.31e-06)
# SUCCEESS: virtual control and trust region < tol
# final time 7.2495603290843835

# %%
tbar = np.array([i for i in range(N+1)]) / N * tfbar

# %% [markdown]
# ## Set MPC controller with static obstacle

# %% [markdown]
# ### nominal trajectory is given as xbar, ubar

# %%
fun_unom = interp1d(tbar,ubar,axis=0)
def get_traj_teval(t_eval) :
    if len(t_eval) == 0 :
        return [],[]
    assert np.max(t_eval) <= tbar[-1]
    def dfdt(t,x) :
        u = fun_unom(t)
        return np.squeeze(myModel.forward(x,u))

    sol = solve_ivp(dfdt,(tbar[0],tbar[-1]),xi,t_eval=t_eval,rtol=1e-12,atol=1e-12)
    return sol.y.T,fun_unom(t_eval)

def forward_dt(dt,xi,u) :
    def dfdt(t,x) :
        return np.squeeze(myModel.forward(x,u))
    sol = solve_ivp(dfdt,(0,dt),xi,rtol=1e-12,atol=1e-12)
    return sol
def get_H_obs(rx,ry) :
    return np.diag([1/rx,1/ry])

# %%
tfsim = 8
horizon = 2
dt = 0.1
Nsim = int(tfsim / dt)
Nmpc =  int(horizon / dt) # N+1 is total discretization points for state
print("Nmpc: {:}".format(Nmpc))

xi_mpc = np.zeros(3)
xi_mpc[0] = -5.0
xi_mpc[1] = -4.0 
xi_mpc[2] = 0
# Out:
# Nmpc: 20

# %%
# cost and constraint / model is identical
MPC_Cost = UnicycleCost.unicycleMPC('Hello',ix,iu,Nmpc)
MPC_Const = UnicycleConstraints.unicycleMPC('Hello',ix,iu)

# # define optimal control
MPC_controller = PTR_in_MPC('unicycle',Nmpc,horizon,max_iter,myModel,MPC_Cost,MPC_Const,myScaling,
          type_discretization="zoh",w_c=1,w_vc=1e3,w_bf=1e3,w_tr=1e-1,w_rate=0,
                            tol_vc=1e-6,tol_bf=1e-3,tol_tr=1e-3)

# %%
# moving obstacle
t_curr = 0
cobs = []
Hobs = []
Aobs = np.array([[1,0],[0,1]])
zobs = np.array([-1/2*dt,-10/8*dt])
Q0 = np.eye(2)*0.1
q0 = np.array([2,5])
# w = np.random.randn(2,1)
# w = alpha*w / np.linalg.norm(w)

def cal_FRS(q,Q,A,z,alpha) :
    qobs = Aobs@q + z
    AQA = A@Q@A.T
    Q2 = np.eye(2) * alpha * alpha
    p = np.sqrt(np.trace(AQA)) / np.sqrt(np.trace(Q2))
    Qobs = (1+1/p)*AQA + (1+p)*Q2
    return qobs,Qobs

def cal_cH_from_qQ(q,Q) :
    c = q
    H = sp.linalg.sqrtm(np.linalg.inv(Q))
    return c,H

# Entire trajectory of FRS of obstacle
alpha = 0.01
csim = []
Hsim = []
for i in range(Nsim+Nmpc+1) :
    if i == 0 :
        q,Q = q0,Q0
    c,H = cal_cH_from_qQ(q,Q)
    csim.append(c)
    Hsim.append(H)
    
    # update q,Q
    q,Q = cal_FRS(q,Q,Aobs,zobs,alpha)

# sample trajectories
w_case = np.array([[-1,0],[1,0],[0,1],[0,-1]])
num_obs = 10
p_traj_list = []
for idx_obs in range(0,num_obs):
    w = np.random.randn(2)
    w = w / np.linalg.norm(w)# * np.random.random()
    p0 = q0 + sp.linalg.sqrtm(Q0)@w
    p_traj = []
    dist = w_case[random.randint(0,3)]
    for i in range(Nsim+1) :
        if i == 0 :
            p = p0
        else :
#             dist = np.random.randn(2)
#             dist = dist / np.linalg.norm(dist)
            p = Aobs@p + zobs + alpha*dist
        p_traj.append(p)
    p_traj_list.append(np.array(p_traj))

# %%
from matplotlib.patches import Rectangle,Ellipse
fig = plt.figure(figsize=(4,4))
ax = fig.add_subplot(111)
fS = 15
for idx_obstacle, (ce,H) in enumerate(zip(csim,Hsim)) :
    rx = 1/H[0,0]
    ry = 1/H[1,1]
    if idx_obstacle == 0:
        circle1 = Ellipse((ce[0],ce[1]),rx*2,ry*2,color='tab:pink',alpha=0.5,fill=True)
    else :
        circle1 = Ellipse((ce[0],ce[1]),rx*2,ry*2,color='tab:pink',alpha=0.5,fill=True)
    ax.add_patch(circle1)
for p_traj in p_traj_list :
    plt.plot(p_traj[:,0], p_traj[:,1],'-', linewidth=2.0,color='tab:red',alpha=0.5)

plt.gca().set_aspect('equal', adjustable='box')
plt.axis([-6, 6, -6, 6])
plt.xlabel('X (m)', fontsize = fS)
plt.ylabel('Y (m)', fontsize = fS)
plt.legend(fontsize=fS)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # MPC starts

# %%
t_curr = 0
x_curr = np.copy(xi_mpc)

t_save,x_save,u_save = [],[],[]
t_save.append(t_curr)
x_save.append(xi_mpc)

t_traj,x_traj,u_traj = [],[],[]
c_traj,H_traj = [],[]

FRS_obstacle = 'Ellipse' 

for idx_sim in range(Nsim) :
    print("t curr: {:.2f}  ======================".format(t_curr))
    # estimating nominal trajectory within horizon
    t_horizon = np.array([t_curr + dt*i for i in range(Nmpc+1)])
    t_eval = t_horizon[t_horizon <= tfbar]
    t_end = t_horizon[t_horizon > tfbar]
    xfwd,ufwd = get_traj_teval(t_eval)
    for _ in t_end :
        if len(xfwd) == 0 :
            xfwd = xbar[-1]
            ufwd = ubar[-1]
        else :
            xfwd = np.vstack((xfwd,xbar[-1]))
            ufwd = np.vstack((ufwd,ubar[-1]))


    # estimate the model of non-cooperative agent
    
    
    # moving obstacle
    cmpc,Hmpc = csim[idx_sim:idx_sim+Nmpc+1],Hsim[idx_sim:idx_sim+Nmpc+1]
        
    # solve optimal control
    # initiall condition
    if t_curr == 0 :
        x0 = xfwd
        u0 = ufwd
    else :
        x0 = np.copy(xmpc)
        x0[:Nmpc] = xmpc[1:]
        u0 = np.copy(umpc)
        u0[:Nmpc] = umpc[1:]


    _,_,xmpc,umpc,num_iter,flag_boundary,l,l_vc,l_tr,_,_,_  = MPC_controller.run(x0,u0,x_curr,xfwd,ufwd,cmpc,Hmpc)

    # apply input to the system (integration)
    sol = forward_dt(dt,x_curr,umpc[0])
    t_curr += dt
    x_curr = sol.y.T[-1]

    # save
    t_save.append(t_curr)
    x_save.append(x_curr)
    u_save.append(umpc[0])

    t_traj.append(t_horizon)
    x_traj.append(xmpc)
    u_traj.append(umpc)
    c_traj.append(cmpc)
    H_traj.append(Hmpc)
#     break

x_save = np.array(x_save)
u_save = np.array(u_save)
# Out:
# t curr: 0.00  ======================
# iteration   total_cost        cost        ||vc||     ||bf||     ||tr||       reduction   w_tr        bounary
# 1           124.495           123.883     2.17e-11    2.63e-14    6.12        876         0.100       0(0.0302)
# 2           134.017           133.982     5.97e-10    3.83e-14    0.355       -9.52       0.100       0(0.00112)
# 3           133.821           133.813     2.15e-10    3.11e-14    0.0828      0.196       0.100       1(0.000326)
# 4           133.848           133.847     5.18e-10    2.64e-13    0.00688     -0.0266     0.100       1(6.31e-05)
# 5           133.853           133.853     2.6e-10     1.16e-13    0.00117     -0.00528    0.100       1(7.09e-06)
# 6           133.854           133.854     1.56e-10    2.69e-14    0.000114    -0.00081    0.100       1(1.24e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 0.10  ======================
# 1           122.312           122.297     4.37e-10    8.62e-14    0.147       878         0.100       1(0.000324)
# 2           122.298           122.298     4.37e-10    2.01e-14    8.78e-05    0.0145      0.100       1(2.32e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 0.20  ======================
# 1           110.829           110.814     3.23e-10    3.12e-13    0.149       889         0.100       1(0.000264)
# 2           110.814           110.814     3.85e-10    5.03e-13    7.22e-05    0.0148      0.100       1(1.91e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 0.30  ======================
# 1           100.258           100.243     2.61e-10    1.34e-13    0.15        900         0.100       1(0.000214)
# 2           100.243           100.243     2.7e-10     1.49e-13    6.26e-05    0.015       0.100       1(1.56e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 0.40  ======================
# 1           91.170            91.155      2.38e-10    5.06e-14    0.151       909         0.100       1(0.000176)
# 2           91.155            91.155      2.37e-10    5.17e-14    5.67e-05    0.0152      0.100       1(1.27e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 0.50  ======================
# 1           83.769            83.754      1.63e-10    1.85e-15    0.152       916         0.100       1(0.000146)
# 2           83.754            83.754      1.59e-10    1.69e-15    5.3e-05     0.0153      0.100       1(1.03e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 0.60  ======================
# 1           78.027            78.011      2.39e-10    8.39e-14    0.153       922         0.100       1(0.000124)
# 2           78.011            78.011      2.38e-10    8.33e-14    5.06e-05    0.0154      0.100       1(8.46e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 0.70  ======================
# 1           73.780            73.764      1.49e-10    3.78e-14    0.153       926         0.100       1(0.000107)
# 2           73.764            73.764      1.5e-10     3.82e-14    4.91e-05    0.0155      0.100       1(6.95e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 0.80  ======================
# 1           70.833            70.817      3.32e-10    4.06e-14    0.154       929         0.100       1(9.3e-05)
# 2           70.817            70.817      3.38e-10    4.2e-14     4.81e-05    0.0156      0.100       1(5.72e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 0.90  ======================
# 1           68.957            68.942      1.3e-10     7.19e-15    0.154       931         0.100       1(8.17e-05)
# 2           68.941            68.941      1.28e-10    6.96e-15    4.75e-05    0.0156      0.100       1(4.72e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 1.00  ======================
# 1           67.917            67.901      2.36e-10    1.54e-13    0.154       932         0.100       1(7.21e-05)
# 2           67.901            67.901      2.47e-10    1.64e-13    4.7e-05     0.0156      0.100       1(3.9e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 1.10  ======================
# 1           67.461            67.445      1.03e-10    1.37e-14    0.154       933         0.100       1(6.36e-05)
# 2           67.445            67.445      2.92e-10    1.37e-13    4.67e-05    0.0156      0.100       1(3.24e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 1.20  ======================
# 1           67.376            67.360      7.84e-11    2.77e-14    0.154       933         0.100       1(5.59e-05)
# 2           67.360            67.360      2.2e-10     1.55e-14    4.66e-05    0.0157      0.100       1(2.68e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 1.30  ======================
# 1           67.501            67.485      2.17e-10    4.94e-13    0.154       932         0.100       1(4.88e-05)
# 2           67.485            67.485      1.75e-10    2.78e-13    4.64e-05    0.0157      0.100       1(2.23e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 1.40  ======================
# 1           67.725            67.710      1.04e-10    2.5e-13     0.154       932         0.100       1(4.19e-05)
# 2           67.710            67.710      9.72e-11    5.58e-14    4.64e-05    0.0157      0.100       1(1.84e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 1.50  ======================
# 1           67.981            67.965      9e-11       9.17e-15    0.154       932         0.100       1(3.53e-05)
# 2           67.965            67.965      1.53e-10    2.75e-14    4.62e-05    0.0157      0.100       1(1.52e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 1.60  ======================
# 1           68.229            68.213      1.39e-10    2.26e-13    0.154       932         0.100       1(2.89e-05)
# 2           68.213            68.213      1.3e-10     1.16e-13    4.63e-05    0.0157      0.100       1(1.25e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 1.70  ======================
# 1           68.449            68.434      3.84e-11    4.87e-15    0.154       932         0.100       1(2.28e-05)
# 2           68.434            68.434      2.03e-10    1.8e-13     4.6e-05     0.0157      0.100       1(1.02e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 1.80  ======================
# 1           70.833            70.832      1.91e-10    8.44e-12    0.00788     929         0.100       1(4.69e-05)
# 2           70.833            70.833      1.92e-10    8.14e-12    3.82e-06    8.18e-05    0.100       1(5.87e-08)
# SUCCEESS: virtual control and trust region < tol
# t curr: 1.90  ======================
# 1           81.552            81.525      2.94e-10    1.28e-12    0.27        918         0.100       1(5.1e-05)
# 2           81.521            81.521      2.99e-10    1.74e-12    0.000198    0.0302      0.100       1(8.26e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 2.00  ======================
# 1           101.190           101.141     2.34e-10    1.35e-11    0.491       899         0.100       1(2.75e-05)
# 2           101.138           101.138     3.55e-10    1.9e-11     2.46e-05    0.0523      0.100       1(1.37e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 2.10  ======================
# 1           131.726           131.680     4.07e-10    2.15e-11    0.469       868         0.100       1(0.000684)
# 2           131.662           131.662     4.96e-10    2.87e-11    0.00068     0.0646      0.100       1(4.22e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 2.20  ======================
# 1           175.115           175.071     3.11e-11    6.71e-12    0.442       825         0.100       0(0.00185)
# 2           174.922           174.922     5.99e-12    2.96e-12    0.0054      0.193       0.100       1(3.44e-05)
# 3           174.851           174.851     4.11e-11    8.71e-12    0.00193     0.0712      0.100       1(8.38e-06)
# 4           174.814           174.814     1.61e-10    9.55e-12    0.00103     0.0371      0.100       1(4.28e-06)
# 5           174.794           174.794     1.89e-10    1.09e-11    0.000541    0.0196      0.100       1(2.23e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 2.30  ======================
# 1           231.570           231.530     1.09e-11    3.25e-11    0.395       768         0.100       0(0.00336)
# 2           230.475           230.471     1.3e-11     3.19e-11    0.0369      1.09        0.100       1(0.000249)
# 3           229.529           229.526     1.35e-11    2.99e-11    0.0302      0.946       0.100       1(0.000137)
# 4           228.549           228.546     3.77e-11    4.52e-11    0.0309      0.98        0.100       1(0.000131)
# 5           227.405           227.401     1.3e-11     2.56e-11    0.0354      1.14        0.100       1(0.000168)
# 6           225.875           225.870     1.03e-11    2.02e-11    0.045       1.53        0.100       1(0.000267)
# 7           223.314           223.307     1.6e-11     4.36e-12    0.0754      2.56        0.100       1(0.000509)
# 8           217.470           217.451     1.24e-09    2.25e-10    0.188       5.84        0.100       0(0.00128)
# 9           198.890           198.778     6.25e-10    1.54e-10    1.12        18.6        0.100       0(0.0143)
# 10          163.277           163.012     3.94e-10    7.28e-11    2.65        35.6        0.100       0(0.035)
# 11          150.586           150.423     2.27e-10    1.57e-12    1.63        12.7        0.100       0(0.00757)
# 12          149.399           149.385     2.94e-10    4.29e-11    0.137       1.19        0.100       0(0.00124)
# 13          148.480           148.470     3.13e-10    6.24e-12    0.0922      0.919       0.100       0(0.00165)
# 14          148.456           148.454     1e-09       1.07e-10    0.0145      0.0239      0.100       1(0.000181)
# 15          148.461           148.461     2.88e-10    2.84e-11    0.00395     -0.00527    0.100       1(5.42e-05)
# 16          148.464           148.464     9.95e-10    6.47e-11    0.00105     -0.00328    0.100       1(1.33e-05)
# 17          148.465           148.465     1.83e-10    1.84e-11    0.000268    -0.0011     0.100       1(3.83e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 2.40  ======================
# 1           154.925           154.900     3.93e-10    4.32e-11    0.247       845         0.100       0(0.00183)
# 2           154.496           154.494     3.5e-10     2.58e-12    0.0129      0.429       0.100       1(0.000138)
# 3           154.455           154.455     3.95e-10    2.41e-11    0.00164     0.0402      0.100       1(1.36e-05)
# 4           154.449           154.449     5.2e-10     3.16e-11    0.000268    0.00609     0.100       1(3.63e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 2.50  ======================
# 1           159.172           159.149     1.11e-09    8.84e-11    0.233       841         0.100       0(0.00101)
# 2           158.852           158.851     1.6e-09     1.31e-10    0.00812     0.32        0.100       1(8.26e-05)
# 3           158.829           158.828     3.54e-10    3.31e-11    0.00105     0.0232      0.100       1(8.48e-06)
# 4           158.825           158.825     7.32e-10    6.03e-11    0.00016     0.00335     0.100       1(2.21e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 2.60  ======================
# 1           162.000           161.979     2.11e-09    1.76e-10    0.213       838         0.100       1(0.000615)
# 2           161.794           161.793     1.07e-09    7.3e-11     0.00478     0.206       0.100       1(3.93e-05)
# 3           161.784           161.783     1.11e-09    7.53e-11    0.000577    0.0101      0.100       1(3.87e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 2.70  ======================
# 1           163.728           163.709     5.77e-10    4.44e-11    0.193       836         0.100       1(0.000575)
# 2           163.596           163.596     1.37e-09    9.43e-11    0.00283     0.132       0.100       1(1.79e-05)
# 3           163.592           163.592     6.08e-10    3.59e-11    0.00032     0.00428     0.100       1(1.96e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 2.80  ======================
# 1           164.558           164.540     6.75e-10    5.11e-11    0.178       835         0.100       1(0.00082)
# 2           164.478           164.478     6.6e-10     5.06e-11    0.00176     0.0801      0.100       1(1.18e-05)
# 3           164.477           164.477     6.55e-10    5.01e-11    0.000167    0.00124     0.100       1(7.81e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 2.90  ======================
# 1           164.627           164.610     1.48e-09    1.15e-10    0.167       835         0.100       1(0.000905)
# 2           164.577           164.577     1.44e-09    1.14e-10    0.00116     0.0499      0.100       1(7.8e-06)
# 3           164.577           164.577     1.43e-09    1.13e-10    8.53e-05    0.000105    0.100       1(3.6e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 3.00  ======================
# 1           163.963           163.947     1.51e-09    1.28e-10    0.16        836         0.100       1(0.000902)
# 2           163.930           163.930     1.45e-09    1.26e-10    0.0008      0.0332      0.100       1(6.94e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 3.10  ======================
# 1           162.517           162.501     7.37e-10    6.44e-11    0.158       837         0.100       1(0.000889)
# 2           162.494           162.494     7.43e-10    6.6e-11     0.000626    0.0232      0.100       1(6.63e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 3.20  ======================
# 1           160.169           160.153     5.47e-10    5.62e-11    0.155       840         0.100       1(0.000816)
# 2           160.150           160.150     5.6e-10     5.84e-11    0.000448    0.0186      0.100       1(5.98e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 3.30  ======================
# 1           156.771           156.756     3.47e-10    4.53e-11    0.154       843         0.100       1(0.000737)
# 2           156.755           156.755     3.4e-10     4.44e-11    0.000322    0.0163      0.100       1(5.26e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 3.40  ======================
# 1           152.217           152.202     5.74e-10    4.33e-11    0.153       848         0.100       1(0.000663)
# 2           152.202           152.202     6.12e-10    4.65e-11    0.000235    0.0152      0.100       1(4.54e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 3.50  ======================
# 1           146.550           146.535     2.44e-10    5.45e-11    0.153       853         0.100       1(0.000596)
# 2           146.535           146.535     2.52e-10    5.51e-11    0.000176    0.0148      0.100       1(3.87e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 3.60  ======================
# 1           140.126           140.111     3.56e-10    6.4e-11     0.153       860         0.100       1(0.000537)
# 2           140.111           140.111     9.41e-10    8.16e-11    0.000136    0.0147      0.100       1(3.28e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 3.70  ======================
# 1           133.696           133.681     2.78e-10    5.25e-11    0.153       866         0.100       1(0.000481)
# 2           133.681           133.681     2.86e-10    5.18e-11    0.000108    0.0147      0.100       1(2.76e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 3.80  ======================
# 1           127.944           127.929     4.24e-10    1.22e-10    0.153       872         0.100       1(0.000424)
# 2           127.930           127.930     2.42e-10    6.16e-11    8.83e-05    0.0148      0.100       1(2.32e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 3.90  ======================
# 1           112.482           112.467     1.43e-11    1.36e-11    0.153       888         0.100       1(0.000358)
# 2           112.467           112.467     1.8e-11     1.48e-11    7.48e-05    0.015       0.100       1(1.93e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 4.00  ======================
# 1           101.728           101.713     3.96e-10    2.86e-13    0.153       898         0.100       1(0.000273)
# 2           101.713           101.713     3.69e-10    3.9e-13     6.47e-05    0.0152      0.100       1(1.58e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 4.10  ======================
# 1           92.805            92.790      1.16e-11    2.54e-14    0.154       907         0.100       1(0.000152)
# 2           92.790            92.790      1.05e-11    1.96e-14    5.73e-05    0.0155      0.100       1(1.25e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 4.20  ======================
# 1           85.857            85.842      4.47e-10    4.91e-14    0.154       914         0.100       1(2.7e-05)
# 2           85.842            85.842      3.08e-10    1e-14       5.17e-05    0.0158      0.100       1(9.23e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 4.30  ======================
# 1           80.680            80.665      1.03e-10    1.46e-14    0.154       919         0.100       1(0.000285)
# 2           80.664            80.664      1.28e-10    2.03e-14    4.84e-05    0.016       0.100       1(5.64e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 4.40  ======================
# 1           76.956            76.941      2.26e-10    6.18e-14    0.156       923         0.100       1(0.000662)
# 2           76.940            76.940      4.48e-10    2.95e-13    4.93e-05    0.0162      0.100       1(1.39e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 4.50  ======================
# 1           74.387            74.371      1.12e-10    5.17e-14    0.159       926         0.100       0(0.00121)
# 2           74.371            74.371      1.16e-10    6.43e-14    5.96e-05    0.0161      0.100       1(4.17e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 4.60  ======================
# 1           72.736            72.719      3.18e-10    6.81e-13    0.166       927         0.100       0(0.0019)
# 2           72.720            72.720      3.06e-10    5.18e-13    8.61e-05    0.0153      0.100       1(1.04e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 4.70  ======================
# 1           71.817            71.800      3.27e-10    2.9e-12     0.176       928         0.100       0(0.00262)
# 2           71.804            71.804      1.8e-10     2.24e-13    0.000131    0.0137      0.100       1(1.72e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 4.80  ======================
# 1           71.451            71.432      1.71e-10    5.29e-14    0.186       929         0.100       0(0.00319)
# 2           71.439            71.439      2.9e-10     2.04e-13    0.000184    0.0114      0.100       1(2.29e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 4.90  ======================
# 1           71.476            71.456      1.99e-10    1.1e-12     0.194       929         0.100       0(0.00361)
# 2           71.467            71.467      2.21e-10    1.44e-12    0.000233    0.0089      0.100       1(2.72e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 5.00  ======================
# 1           71.767            71.747      2.09e-10    1.04e-13    0.2         928         0.100       0(0.00392)
# 2           71.761            71.761      1.74e-10    6.63e-14    0.000276    0.00658     0.100       1(3.03e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 5.10  ======================
# 1           72.235            72.214      4.73e-10    2.75e-12    0.204       928         0.100       0(0.00413)
# 2           72.230            72.230      1.74e-10    6.1e-13     0.000309    0.00459     0.100       1(3.25e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 5.20  ======================
# 1           72.814            72.793      1.94e-10    6.13e-13    0.207       927         0.100       0(0.00428)
# 2           72.811            72.811      1.51e-10    6.37e-14    0.000334    0.00301     0.100       1(3.39e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 5.30  ======================
# 1           72.276            72.260      1.53e-10    8.71e-14    0.157       928         0.100       0(0.00321)
# 2           72.276            72.276      4.18e-10    2.94e-12    0.00024     7.9e-05     0.100       1(2.22e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 5.40  ======================
# 1           70.160            70.151      3.36e-10    2.36e-13    0.0843      930         0.100       0(0.00168)
# 2           70.161            70.161      3.52e-10    3.28e-13    0.000114    -0.000872   0.100       1(8.81e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 5.50  ======================
# 1           67.209            67.205      3.08e-10    4.74e-13    0.0454      933         0.100       1(0.000884)
# 2           67.210            67.210      2.36e-10    3.53e-13    5.55e-05    -0.000528   0.100       1(3.69e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 5.60  ======================
# 1           63.815            63.812      2.04e-10    1.61e-13    0.0245      936         0.100       1(0.000471)
# 2           63.815            63.815      2e-10       2.07e-13    2.78e-05    -0.000195   0.100       1(1.59e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 5.70  ======================
# 1           60.184            60.183      3.85e-10    1.94e-12    0.0133      940         0.100       1(0.000253)
# 2           60.184            60.184      3.05e-10    1.43e-12    1.43e-05    -3.87e-05   0.100       1(6.84e-08)
# SUCCEESS: virtual control and trust region < tol
# t curr: 5.80  ======================
# 1           56.427            56.426      3.81e-10    3.35e-12    0.00726     944         0.100       1(0.000136)
# 2           56.427            56.427      2.48e-10    6.53e-13    7.61e-06    9.32e-06    0.100       1(3.34e-08)
# SUCCEESS: virtual control and trust region < tol
# t curr: 5.90  ======================
# 1           52.604            52.603      3.08e-10    1.68e-12    0.00397     947         0.100       1(7.35e-05)
# 2           52.604            52.604      1.39e-10    3.98e-14    4.15e-06    1.23e-05    0.100       1(1.95e-08)
# SUCCEESS: virtual control and trust region < tol
# t curr: 6.00  ======================
# 1           48.744            48.744      2.31e-10    5.4e-14     0.00219     951         0.100       1(3.97e-05)
# 2           48.744            48.744      2.14e-10    4.26e-14    2.34e-06    2.33e-06    0.100       1(1.11e-08)
# SUCCEESS: virtual control and trust region < tol
# t curr: 6.10  ======================
# 1           44.863            44.863      1.07e-10    1.34e-13    0.00123     955         0.100       1(2.14e-05)
# 2           44.863            44.863      1.63e-10    7.11e-14    1.36e-06    -7.5e-06    0.100       1(6.22e-09)
# SUCCEESS: virtual control and trust region < tol
# t curr: 6.20  ======================
# 1           40.966            40.965      6.5e-11     3.95e-14    0.000699    959         0.100       1(1.15e-05)
# SUCCEESS: virtual control and trust region < tol
# t curr: 6.30  ======================
# 1           37.049            37.049      1.8e-10     5.88e-14    0.000413    963         0.100       1(6.17e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 6.40  ======================
# 1           33.112            33.112      7.73e-11    3.4e-14     0.000254    967         0.100       1(3.32e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 6.50  ======================
# 1           29.159            29.159      1.45e-10    1.44e-14    0.000168    971         0.100       1(1.77e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 6.60  ======================
# 1           25.222            25.222      3.63e-10    1.2e-14     0.000121    975         0.100       1(9.44e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 6.70  ======================
# 1           21.355            21.355      2.03e-10    7.67e-14    9.46e-05    979         0.100       1(5e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 6.80  ======================
# 1           17.630            17.630      2.32e-10    8.66e-15    7.79e-05    982         0.100       1(3.23e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 6.90  ======================
# 1           14.123            14.123      1.83e-10    5.29e-14    6.43e-05    986         0.100       1(2.99e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 7.00  ======================
# 1           10.923            10.923      5.82e-11    1.13e-14    4.97e-05    989         0.100       1(2.46e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 7.10  ======================
# 1           8.108             8.108       1.13e-10    5.65e-15    3.44e-05    992         0.100       1(1.75e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 7.20  ======================
# 1           5.710             5.710       8.24e-11    2.67e-15    2.12e-05    994         0.100       1(1.11e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 7.30  ======================
# 1           3.638             3.638       3.26e-11    5.96e-15    1.21e-05    996         0.100       1(6.56e-08)
# SUCCEESS: virtual control and trust region < tol
# t curr: 7.40  ======================
# 1           2.129             2.129       2.6e-11     1.93e-15    6.63e-06    998         0.100       1(3.7e-08)
# SUCCEESS: virtual control and trust region < tol
# t curr: 7.50  ======================
# 1           1.326             1.326       1.72e-11    1.24e-15    3.55e-06    999         0.100       1(2.04e-08)
# SUCCEESS: virtual control and trust region < tol
# t curr: 7.60  ======================
# 1           0.899             0.899       1.39e-11    7.12e-16    1.88e-06    999         0.100       1(1.09e-08)
# SUCCEESS: virtual control and trust region < tol
# t curr: 7.70  ======================
# 1           0.671             0.671       1.55e-11    2.23e-15    9.86e-07    999         0.100       1(5.8e-09)
# SUCCEESS: virtual control and trust region < tol
# t curr: 7.80  ======================
# 1           0.550             0.550       1.67e-11    2.06e-15    5.15e-07    999         0.100       1(3.05e-09)
# SUCCEESS: virtual control and trust region < tol
# t curr: 7.90  ======================
# 1           0.486             0.486       9.22e-12    4.16e-16    2.68e-07    1e+03       0.100       1(1.58e-09)
# SUCCEESS: virtual control and trust region < tol

# %%
plt.figure(figsize=(15,10))
fS = 18
plt.subplot(231)
plt.plot(xbar[:,0], xbar[:,1],'--', linewidth=2.0)
plt.plot(x_save[:,0], x_save[:,1],'-', linewidth=2.0)
plt.plot(xf[0],xf[1],"o",label='goal')
plt.gca().set_aspect('equal', adjustable='box')
plt.axis([-6, 6, -6, 6])
plt.xlabel('X (m)', fontsize = fS)
plt.ylabel('Y (m)', fontsize = fS)
plt.subplot(232)
plt.plot(tbar, xbar[:,0],'--', linewidth=2.0)
plt.plot(t_save, x_save[:,0],'-',linewidth=2.0)
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('x1 (m)', fontsize = fS)
plt.subplot(233)
plt.plot(tbar, xbar[:,1],'--',linewidth=2.0)
plt.plot(t_save, x_save[:,1],'-',linewidth=2.0)
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('x2 (m)', fontsize = fS)
plt.subplot(234)
plt.plot(tbar, np.rad2deg(xbar[:,2]),'--',linewidth=2.0)
plt.plot(t_save, np.rad2deg(x_save[:,2]),'-',linewidth=2.0)
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('x3 (rad)', fontsize = fS)
plt.subplot(235)
plt.plot(tbar, ubar[:,0],'--',linewidth=2.0)
plt.step(t_save,[*u_save[:,0],u_save[-1,0]],label='zoh',where='post')
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('v (m/s)', fontsize = fS)
plt.subplot(236)
plt.plot(tbar, np.rad2deg(ubar[:,1]),'--',linewidth=2.0)
plt.step(t_save,np.rad2deg([*u_save[:,1],u_save[-1,1]]),label='zoh',where='post')
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('w (rad/s)', fontsize = fS)
plt.show()

# %% [markdown]
# ## make a video

# %%
from matplotlib.patches import Rectangle,Ellipse
import imageio.v2 as imageio
import os

# %%
filenames = []
t_curr = 0
for idx in range(Nsim+1) :
    fig = plt.figure(figsize=(10,10))
    ax = fig.add_subplot(111)
    fS = 15
    plt.plot(xbar[:,0], xbar[:,1],'--', linewidth=2.0,label='nominal trajectory')
    plt.plot(x_save[:idx+1,0], x_save[:idx+1,1],'-', linewidth=2.0,label='result trajectory')
    if idx < Nsim :
        plt.plot(x_traj[idx][:,0], x_traj[idx][:,1],'-',color='tab:green', linewidth=2.0,label='future prediction')
        plt.plot(x_traj[idx][0,0], x_traj[idx][0,1],'o',color='tab:green', linewidth=2.0)
#     for ce,H in zip(cobs,Hobs) :
    if idx < Nsim :
        cmpc = c_traj[idx]
        Hmpc = H_traj[idx]
    for idx_obstacle, (ce,H) in enumerate(zip(cmpc,Hmpc)) :
        rx = 1/H[0,0]
        ry = 1/H[1,1]
        if idx_obstacle == 0:
            circle1 = Ellipse((ce[0],ce[1]),rx*2,ry*2,color='tab:pink',alpha=0.5,fill=True)
        else :
            circle1 = Ellipse((ce[0],ce[1]),rx*2,ry*2,color='tab:pink',alpha=0.4*np.exp(-idx_obstacle/10),fill=True)
        ax.add_patch(circle1)
    for p_traj in p_traj_list :
        plt.plot(p_traj[:idx+1,0], p_traj[:idx+1,1],'-',alpha=0.5,linewidth=1.0,color='tab:brown')
        plt.plot(p_traj[idx,0], p_traj[idx,1],'o', linewidth=2.0,color='tab:brown')
    
    plt.gca().set_aspect('equal', adjustable='box')
    plt.axis([-6, 6, -6, 6])
    plt.xlabel('X (m)', fontsize = fS)
    plt.ylabel('Y (m)', fontsize = fS)
    plt.plot(-1e3,-1e3,'o',color='tab:pink',label='forward reachable sets')
    plt.legend(fontsize=fS)

    filename = '../images/{:d}.png'.format(idx)
    plt.savefig(filename)
    filenames.append(filename)
    plt.close()
    t_curr += dt

# %%
img_name = 'MPC_moving_obstacle_' + FRS_obstacle
with imageio.get_writer('../images/'+img_name+'.gif', mode='I') as writer:
        for filename in filenames:
            image = imageio.imread(filename)
            writer.append_data(image)

# %%
img_name = 'video_MPC_moving_obstacle_' + FRS_obstacle
with imageio.get_writer('../images/'+img_name+'.mov', fps=int(1/dt)) as writer:
    for filename in filenames:
        image = imageio.imread(filename)
        writer.append_data(image)

# %%
for filename in set(filenames):
    os.remove(filename)

# %%
filenames = []
t_curr = 0
# for idx in range(Nsim+1) :
idx = 0
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
fS = 15
plt.plot(xbar[:,0], xbar[:,1],'--', linewidth=2.0,label='nominal trajectory')
plt.plot(x_save[:idx+1,0], x_save[:idx+1,1],'-', linewidth=2.0,label='history')

if idx < Nsim :
    plt.plot(x_traj[idx][:,0], x_traj[idx][:,1],'-',color='tab:green', linewidth=2.0,label='future prediction')
    plt.plot(x_traj[idx][0,0], x_traj[idx][0,1],'o',color='tab:green', linewidth=2.0)
    cmpc = c_traj[idx]
    Hmpc = H_traj[idx]
    
for idx_obstacle, (ce,H) in enumerate(zip(cmpc,Hmpc)) :
    rx = 1/H[0,0]
    ry = 1/H[1,1]
    if idx_obstacle == 0:
        circle1 = Ellipse((ce[0],ce[1]),rx*2,ry*2,color='tab:red',alpha=1.0,fill=True)
    else :
        circle1 = Ellipse((ce[0],ce[1]),rx*2,ry*2,color='tab:pink',alpha=0.2*np.exp(-idx_obstacle/10),fill=True)
    ax.add_patch(circle1)

plt.gca().set_aspect('equal', adjustable='box')
plt.axis([-6, 6, -6, 6])
plt.xlabel('X (m)', fontsize = fS)
plt.ylabel('Y (m)', fontsize = fS)
plt.legend(fontsize=fS)
