# %%
import matplotlib.pyplot as plt
# %matplotlib inline  
# %load_ext autoreload
# %autoreload 2
import numpy as np
import time
import random
def print_np(x):
    print ("Type is %s" % (type(x)))
    print ("Shape is %s" % (x.shape,))
#     print ("Values are: \n%s" % (x))

# %%
import sys
# sys.path.append('../')
sys.path.append('../')
sys.path.append('../model')
sys.path.append('../cost')
sys.path.append('../constraints')
import UnicycleModel
import FinaltimeFreeCost
import UnicycleCost
import UnicycleConstraints
from scipy.integrate import solve_ivp
from PTR_tf_free import PTR_tf_free
from PTR_in_MPC import PTR_in_MPC
from Scaling import TrajectoryScaling
from scipy.interpolate import interp1d
from scipy.integrate import solve_ivp
# Out:
# (CVXPY) Sep 07 11:22:35 AM: Encountered unexpected exception importing solver SCS:
# ImportError("dlopen(/opt/anaconda3/envs/py309/lib/python3.9/site-packages/_scs_direct.cpython-39-darwin.so, 0x0002): Library not loaded: @rpath/liblapack.3.dylib\n  Referenced from: /opt/anaconda3/envs/py309/lib/python3.9/site-packages/_scs_direct.cpython-39-darwin.so\n  Reason: tried: '/opt/anaconda3/envs/py309/lib/python3.9/site-packages/../../liblapack.3.dylib' (no such file), '/opt/anaconda3/envs/py309/lib/python3.9/site-packages/../../liblapack.3.dylib' (no such file), '/opt/anaconda3/envs/py309/bin/../lib/liblapack.3.dylib' (no such file), '/opt/anaconda3/envs/py309/bin/../lib/liblapack.3.dylib' (no such file), '/usr/local/lib/liblapack.3.dylib' (no such file), '/usr/lib/liblapack.3.dylib' (no such file)")

# %% [markdown]
# ## Nominal trajectory generation

# %%
ix = 3
iu = 2
ih = 2
N = 50
tf = 10
delT = tf/N
max_iter = 30

# %%
x_max = np.array([5,5,np.deg2rad(90)])
x_min = np.zeros(ix)

u_max = np.array([2,np.deg2rad(90)]) 
u_min = np.array([0,0])


myScaling = TrajectoryScaling(x_min,x_max,u_min,u_max,tf)
Sx,iSx,sx,Su,iSu,su = myScaling.get_scaling()

# %%
myModel = UnicycleModel.unicycle('Hello',ix,iu,'numeric_central')
myCost = FinaltimeFreeCost.Finaltime('Hello',ix,iu,N)
myConst = UnicycleConstraints.UnicycleConstraints('Hello',ix,iu)

# %%
xi = np.zeros(3)
xi[0] = -5.0
xi[1] = -5.0 
xi[2] = 0

xf = np.zeros(3)
xf[0] = 5.0
xf[1] = 5.0
xf[2] = 0


x0 = np.zeros((N+1,ix))
for i in range(N+1) :
    x0[i] = (N-i)/N * xi + i/N * xf
    
u0 = np.zeros((N+1,iu))
ui = np.array([2,0])
uf = np.array([2,0])

for i in range(N+1) :
    u0[i] = (N-i)/N * ui + i/N * uf

# %%
TrajOpt = PTR_tf_free('unicycle',N,tf,max_iter,myModel,myCost,myConst,myScaling,
          type_discretization="foh",w_c=1,w_vc=1e3,w_tr=1e-1,w_rate=0,tol_vc=1e-6,tol_tr=1e-3)
xfwd,ufwd,xbar,ubar,tfbar,total_num_iter,flag_boundary,l,l_vc,l_tr,x_traj,u_traj,T_traj  = TrajOpt.run(x0,u0,xi,xf)
print("final time {:}".format(tfbar))
# Out:
# iteration   total_cost        cost        ||vc||     ||tr||       reduction   w_tr        dynamics
# 1           5.696             5.000       1.95e-12    6.96        4.3         0.100       0(0.128)
# 2           7.734             6.976       3.95e-12    7.57        -2.04       0.100       0(0.0652)
# 3           7.324             7.132       3.9e-13     1.92        0.409       0.100       0(0.0153)
# 4           7.256             7.253       1.06e-11    0.0302      0.0685      0.100       1(0.000274)
# 5           7.252             7.251       8.5e-12     0.0098      0.00348     0.100       1(2.3e-05)
# 6           7.251             7.250       1.46e-12    0.00635     0.00153     0.100       1(1.8e-05)
# 7           7.250             7.250       1.01e-12    0.00157     0.000715    0.100       1(3.7e-06)
# 8           7.250             7.250       8.91e-13    0.00109     0.000236    0.100       1(1.6e-06)
# 9           7.250             7.250       7.81e-13    0.000881    0.000185    0.100       1(1.31e-06)
# SUCCEESS: virtual control and trust region < tol
# final time 7.2495603290843835

# %%
tbar = np.array([i for i in range(N+1)]) / N * tfbar

# %% [markdown]
# ## Set MPC controller with static obstacle

# %% [markdown]
# ### nominal trajectory is given as xbar, ubar

# %%
fun_unom = interp1d(t_index,ubar,axis=0)
def get_traj_teval(t_eval) :
    if len(t_eval) == 0 :
        return [],[]
    assert np.max(t_eval) <= t_index[-1]
    def dfdt(t,x) :
        u = fun_unom(t)
        return np.squeeze(myModel.forward(x,u))

    sol = solve_ivp(dfdt,(t_index[0],t_index[-1]),xi,t_eval=t_eval,rtol=1e-12,atol=1e-12)
    return sol.y.T,fun_unom(t_eval)

def forward_dt(dt,xi,u) :
    def dfdt(t,x) :
        return np.squeeze(myModel.forward(x,u))
    sol = solve_ivp(dfdt,(0,dt),xi,rtol=1e-12,atol=1e-12)
    return sol
def get_H_obs(rx,ry) :
    return np.diag([1/rx,1/ry])

# %%
tbar = np.array([i for i in range(N+1)]) / N * tfbar
tfsim = 8
horizon = 2
dt = 0.1
Nsim = int(tfsim / dt)
Nmpc =  int(horizon / dt) # N+1 is total discretization points for state
print("Nmpc: {:}".format(Nmpc))

xi_mpc = np.zeros(3)
xi_mpc[0] = -5.0
xi_mpc[1] = -4.0 
xi_mpc[2] = 0
# Out:
# Nmpc: 20

# %%
# cost and constraint / model is identical
MPC_Cost = UnicycleCost.unicycleMPC('Hello',ix,iu,Nmpc)
MPC_Const = UnicycleConstraints.unicycleMPC('Hello',ix,iu)

# # define optimal control
MPC_controller = PTR_in_MPC('unicycle',Nmpc,horizon,max_iter,myModel,MPC_Cost,MPC_Const,myScaling,
          type_discretization="zoh",w_c=1,w_vc=1e3,w_bf=1e3,w_tr=1e-1,w_rate=0,
                            tol_vc=1e-6,tol_bf=1e-3,tol_tr=1e-3)

# %%
# moving obstacle
t_curr = 0
cobs = []
Hobs = []
    
def fun_obstacle(t_eval) :
    t_eval = np.array(t_eval)
    N = len(t_eval)
    x = -0.5*t_eval + 2
    y = -10/8*t_eval + 5
    cobs = []
    Hobs = []
    H = get_H_obs(1,1) # fixed radius
    for i in range(N) :
        cobs.append([x[i],y[i]])
        Hobs.append(H)
    return cobs,Hobs

# %%
t_curr = 0
x_curr = np.copy(xi_mpc)

t_save,x_save,u_save = [],[],[]
t_save.append(t_curr)
x_save.append(xi_mpc)

t_traj,x_traj,u_traj = [],[],[]
c_traj,H_traj = [],[]

FRS_obstacle = 'proactive' 

for idx_sim in range(Nsim) :
    print("t curr: {:.2f}  ======================".format(t_curr))
    # estimating nominal trajectory within horizon
    t_horizon = np.array([t_curr + dt*i for i in range(Nmpc+1)])
    t_eval = t_horizon[t_horizon <= tfbar]
    t_end = t_horizon[t_horizon > tfbar]
    xfwd,ufwd = get_traj_teval(t_eval)
    for _ in t_end :
        if len(xfwd) == 0 :
            xfwd = xbar[-1]
            ufwd = ubar[-1]
        else :
            xfwd = np.vstack((xfwd,xbar[-1]))
            ufwd = np.vstack((ufwd,ubar[-1]))


    # estimate the model of non-cooperative agent
    
    
    # moving obstacle
    cmpc,Hmpc = [],[]
    if FRS_obstacle == 'reactive' :
        ctmp,Htmp = fun_obstacle([t_curr])
        c = ctmp[0]
        H = Htmp[0]
        for i in range(Nmpc+1) :
            cmpc.append(c)
            Hmpc.append(H)   
    elif FRS_obstacle == 'proactive' :
        cmpc,Hmpc = fun_obstacle(t_horizon)
    
    # solve optimal control
    # initiall condition
    if t_curr == 0 :
        x0 = xfwd
        u0 = ufwd
    else :
        x0 = np.copy(xmpc)
        x0[:Nmpc] = xmpc[1:]
        u0 = np.copy(umpc)
        u0[:Nmpc] = umpc[1:]


    _,_,xmpc,umpc,num_iter,flag_boundary,l,l_vc,l_tr,_,_,_  = MPC_controller.run(x0,u0,x_curr,xfwd,ufwd,cmpc,Hmpc)

    # apply input to the system (integration)
    sol = forward_dt(dt,x_curr,umpc[0])
    t_curr += dt
    x_curr = sol.y.T[-1]

    # save
    t_save.append(t_curr)
    x_save.append(x_curr)
    u_save.append(umpc[0])

    t_traj.append(t_horizon)
    x_traj.append(xmpc)
    u_traj.append(umpc)
    c_traj.append(cmpc)
    H_traj.append(Hmpc)
#     break

x_save = np.array(x_save)
u_save = np.array(u_save)
# Out:
# t curr: 0.00  ======================
# 1           124.495           123.883     2.22e-10    5.3e-14     6.12        876         0.100       0(0.0302)
# 2           134.017           133.982     5.67e-11    3.5e-14     0.355       -9.52       0.100       0(0.00112)
# 3           133.821           133.813     5.63e-11    5.98e-14    0.0828      0.196       0.100       1(0.000326)
# 4           133.848           133.847     5.67e-11    5.56e-14    0.00689     -0.0266     0.100       1(6.31e-05)
# 5           133.853           133.853     5.64e-11    5.92e-14    0.00117     -0.00528    0.100       1(7.1e-06)
# 6           133.854           133.854     5.64e-11    5.85e-14    0.000114    -0.000811   0.100       1(1.24e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 0.10  ======================
# 1           122.312           122.297     5.36e-11    2.44e-14    0.147       878         0.100       1(0.000324)
# 2           122.298           122.298     5.35e-11    2.44e-14    8.78e-05    0.0145      0.100       1(2.32e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 0.20  ======================
# 1           110.829           110.814     1.05e-11    2.16e-14    0.149       889         0.100       1(0.000264)
# 2           110.814           110.814     1.05e-11    2.14e-14    7.22e-05    0.0148      0.100       1(1.91e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 0.30  ======================
# 1           100.258           100.243     1.27e-11    1.35e-13    0.15        900         0.100       1(0.000214)
# 2           100.243           100.243     1.09e-11    1.05e-13    6.26e-05    0.015       0.100       1(1.56e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 0.40  ======================
# 1           91.170            91.155      1.16e-11    9.03e-14    0.151       909         0.100       1(0.000176)
# 2           91.155            91.155      1.15e-11    9.35e-14    5.67e-05    0.0152      0.100       1(1.27e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 0.50  ======================
# 1           83.769            83.754      6.04e-12    2.03e-14    0.152       916         0.100       1(0.000146)
# 2           83.754            83.754      6.18e-12    2.11e-14    5.3e-05     0.0153      0.100       1(1.03e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 0.60  ======================
# 1           78.027            78.011      3.5e-10     2.08e-13    0.153       922         0.100       1(0.000124)
# 2           78.011            78.011      4.61e-10    5.77e-14    5.06e-05    0.0154      0.100       1(8.46e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 0.70  ======================
# 1           73.780            73.764      1.45e-10    1.33e-14    0.153       926         0.100       1(0.000107)
# 2           73.764            73.764      4.36e-10    4.95e-13    4.9e-05     0.0155      0.100       1(6.94e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 0.80  ======================
# 1           70.833            70.817      2.82e-10    1.03e-12    0.154       929         0.100       1(9.3e-05)
# 2           70.817            70.817      2.36e-10    1.32e-13    4.81e-05    0.0156      0.100       1(5.72e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 0.90  ======================
# 1           68.957            68.942      1.39e-10    6.4e-14     0.154       931         0.100       1(8.17e-05)
# 2           68.941            68.941      1.84e-10    1.18e-13    4.75e-05    0.0156      0.100       1(4.72e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 1.00  ======================
# 1           67.917            67.901      2.36e-10    8.87e-14    0.154       932         0.100       1(7.21e-05)
# 2           67.901            67.901      1.12e-10    1.14e-14    4.71e-05    0.0156      0.100       1(3.9e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 1.10  ======================
# 1           67.461            67.445      7.96e-11    1.12e-13    0.154       933         0.100       1(6.37e-05)
# 2           67.445            67.445      1.53e-10    2.85e-13    4.67e-05    0.0156      0.100       1(3.24e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 1.20  ======================
# 1           67.376            67.361      1.22e-10    2.02e-13    0.154       933         0.100       1(5.59e-05)
# 2           67.360            67.360      1.89e-10    1.22e-13    4.65e-05    0.0157      0.100       1(2.68e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 1.30  ======================
# 1           67.501            67.485      3.97e-11    3.52e-14    0.154       932         0.100       1(4.87e-05)
# 2           67.485            67.485      1.22e-10    1.84e-13    4.64e-05    0.0157      0.100       1(2.23e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 1.40  ======================
# 1           67.725            67.710      2.04e-10    9.31e-14    0.154       932         0.100       1(4.19e-05)
# 2           67.710            67.710      6.47e-11    6.73e-15    4.62e-05    0.0157      0.100       1(1.84e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 1.50  ======================
# 1           67.981            67.965      8.04e-11    5.41e-14    0.154       932         0.100       1(3.53e-05)
# 2           67.965            67.965      1.38e-10    6.01e-13    4.62e-05    0.0157      0.100       1(1.52e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 1.60  ======================
# 1           68.229            68.213      2.75e-10    1.73e-13    0.154       932         0.100       1(2.89e-05)
# 2           68.213            68.213      1.55e-10    1.84e-13    4.61e-05    0.0157      0.100       1(1.25e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 1.70  ======================
# 1           70.181            70.181      2.14e-10    2.05e-11    0.00136     930         0.100       1(1.53e-05)
# 2           70.181            70.181      2.15e-10    1.93e-11    1.79e-06    -0.000111   0.100       1(7.3e-09)
# SUCCEESS: virtual control and trust region < tol
# t curr: 1.80  ======================
# 1           79.837            79.815      1.52e-12    1.2e-11     0.222       920         0.100       1(0.000126)
# 2           79.814            79.814      1.61e-12    1.22e-11    0.000197    0.0232      0.100       1(7.61e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 1.90  ======================
# 1           97.943            97.900      7.25e-10    1.09e-11    0.433       902         0.100       1(1.66e-05)
# 2           97.898            97.898      4.09e-10    3.28e-11    9.99e-05    0.0453      0.100       1(1.1e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 2.00  ======================
# 1           126.420           126.378     4.24e-10    3.07e-11    0.422       874         0.100       1(0.00022)
# 2           126.377           126.377     4.62e-10    3.31e-11    8.33e-06    0.043       0.100       1(3.79e-08)
# SUCCEESS: virtual control and trust region < tol
# t curr: 2.10  ======================
# 1           167.390           167.349     3.06e-10    2.03e-11    0.409       833         0.100       1(0.00067)
# 2           167.340           167.340     3.54e-10    2.84e-11    0.000264    0.0499      0.100       1(1.52e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 2.20  ======================
# 1           222.806           222.767     3.44e-12    3.96e-11    0.394       777         0.100       0(0.00139)
# 2           222.704           222.704     3.66e-12    4.05e-11    0.00199     0.102       0.100       1(1.21e-05)
# 3           222.680           222.680     3.65e-12    4.01e-11    0.000603    0.0235      0.100       1(1.94e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 2.30  ======================
# 1           294.096           294.059     3.03e-10    7.28e-11    0.375       706         0.100       0(0.00236)
# 2           293.740           293.739     2.65e-10    8.14e-11    0.0105      0.356       0.100       1(5.99e-05)
# 3           293.554           293.554     2.42e-10    8.35e-11    0.00571     0.185       0.100       1(1.98e-05)
# 4           293.443           293.443     1.94e-10    7.52e-11    0.00345     0.111       0.100       1(1.09e-05)
# 5           293.376           293.375     1.48e-10    6.5e-11     0.00211     0.0677      0.100       1(6.54e-06)
# 6           293.334           293.334     1.24e-10    5.96e-11    0.0013      0.0415      0.100       1(3.97e-06)
# 7           293.308           293.308     1.4e-10     7.02e-11    0.000805    0.0257      0.100       1(2.49e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 2.40  ======================
# 1           379.374           379.339     1.72e-10    7.24e-11    0.349       621         0.100       0(0.00315)
# 2           377.644           377.638     4.22e-10    7.32e-11    0.0595      1.73        0.100       1(0.000302)
# 3           376.109           376.103     2.25e-10    1.61e-10    0.0527      1.54        0.100       1(0.000189)
# 4           374.639           374.634     2.11e-10    1.2e-10     0.0488      1.47        0.100       1(0.000225)
# 5           373.091           373.086     3.45e-10    6.1e-11     0.0494      1.55        0.100       1(0.000279)
# 6           371.232           371.226     6.02e-10    8.79e-11    0.057       1.86        0.100       1(0.00038)
# 7           368.601           368.593     3.23e-10    4.7e-11     0.0775      2.63        0.100       1(0.000585)
# 8           363.992           363.979     4.52e-10    6.37e-11    0.132       4.61        0.100       0(0.00112)
# 9           353.334           353.302     4.99e-11    6.07e-11    0.325       10.7        0.100       0(0.00256)
# 10          322.400           322.245     1.44e-09    2.1e-10     1.54        30.9        0.100       0(0.0165)
# 11          267.108           266.758     1.06e-09    2.24e-10    3.5         55.3        0.100       0(0.0246)
# 12          240.677           240.377     7.33e-10    4.22e-10    3           26.4        0.100       0(0.0142)
# 13          236.680           236.623     8.43e-12    2.63e-12    0.567       4           0.100       0(0.00305)
# 14          235.368           235.356     3.72e-10    3.94e-11    0.123       1.31        0.100       0(0.00159)
# 15          235.377           235.373     6.75e-10    1.05e-10    0.038       -0.00895    0.100       1(0.000523)
# 16          235.406           235.404     3.06e-10    3.27e-11    0.021       -0.0287     0.100       1(0.000295)
# 17          235.423           235.422     3.6e-10     3.3e-11     0.0102      -0.0175     0.100       1(0.000138)
# 18          235.433           235.433     3.18e-10    3.29e-11    0.00583     -0.00997    0.100       1(7.71e-05)
# 19          235.439           235.439     3.6e-10     3.62e-11    0.00303     -0.00561    0.100       1(3.96e-05)
# 20          235.442           235.442     3.44e-10    3.5e-11     0.00171     -0.00309    0.100       1(2.22e-05)
# 21          235.444           235.444     3.65e-10    3.65e-11    0.000906    -0.00171    0.100       1(1.18e-05)
# SUCCEESS: virtual control and trust region < tol
# t curr: 2.50  ======================
# 1           243.343           243.315     2.66e-10    4e-11       0.276       757         0.100       0(0.00125)
# 2           242.820           242.819     6.46e-10    1.5e-10     0.0132      0.522       0.100       1(0.000163)
# 3           242.757           242.757     3.4e-10     8.1e-11     0.00258     0.0635      0.100       1(2.36e-05)
# 4           242.742           242.742     2.61e-10    4.46e-11    0.000705    0.0148      0.100       1(1.04e-05)
# SUCCEESS: virtual control and trust region < tol
# t curr: 2.60  ======================
# 1           247.847           247.823     2.09e-10    3.11e-11    0.242       752         0.100       1(0.00078)
# 2           247.510           247.509     1.22e-11    1.29e-12    0.00845     0.338       0.100       1(7.59e-05)
# 3           247.476           247.476     2.46e-11    2.01e-12    0.00193     0.0336      0.100       1(1.34e-05)
# 4           247.467           247.467     1.08e-10    4.41e-11    0.000569    0.00885     0.100       1(6.41e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 2.70  ======================
# 1           250.368           250.347     5.69e-11    1.76e-11    0.21        750         0.100       0(0.00111)
# 2           250.177           250.177     4.83e-11    1.63e-11    0.00528     0.191       0.100       1(3.47e-05)
# 3           250.164           250.164     4.55e-11    1.56e-11    0.00121     0.0133      0.100       1(4.4e-06)
# 4           250.160           250.160     4.23e-11    1.51e-11    0.000356    0.00375     0.100       1(2.28e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 2.80  ======================
# 1           251.374           251.355     6.62e-11    2.22e-11    0.185       749         0.100       0(0.00131)
# 2           251.267           251.267     2.83e-10    1e-10       0.00334     0.107       0.100       1(2.25e-05)
# 3           251.263           251.263     2.16e-10    6.18e-11    0.000682    0.00448     0.100       1(2.56e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 2.90  ======================
# 1           251.093           251.076     2.45e-11    1.17e-11    0.168       749         0.100       0(0.0013)
# 2           251.028           251.028     2.89e-11    1.35e-11    0.0018      0.0649      0.100       1(1.31e-05)
# 3           251.026           251.026     2.94e-11    1.38e-11    0.000238    0.00204     0.100       1(1.83e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 3.00  ======================
# 1           249.531           249.515     2.77e-11    1.34e-11    0.158       750         0.100       0(0.00124)
# 2           249.491           249.491     3.26e-11    1.57e-11    0.00131     0.0395      0.100       1(8.46e-06)
# 3           249.491           249.491     3.06e-11    1.51e-11    0.000145    0.000524    0.100       1(6.36e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 3.10  ======================
# 1           246.538           246.523     2.55e-10    8e-11       0.153       753         0.100       0(0.00114)
# 2           246.512           246.512     5.22e-10    1.45e-10    0.000907    0.0264      0.100       1(6.56e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 3.20  ======================
# 1           241.801           241.786     7.91e-10    8.06e-11    0.152       758         0.100       0(0.00106)
# 2           241.782           241.782     4.81e-10    1.23e-10    0.000738    0.0188      0.100       1(6.56e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 3.30  ======================
# 1           234.859           234.844     6.18e-10    2.65e-10    0.15        765         0.100       1(0.000943)
# 2           234.843           234.843     8.97e-10    3.78e-10    0.000526    0.0157      0.100       1(6.05e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 3.40  ======================
# 1           225.209           225.194     2.49e-10    4.18e-11    0.15        775         0.100       1(0.000836)
# 2           225.195           225.195     1.19e-09    5.44e-10    0.000368    0.0144      0.100       1(5.38e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 3.50  ======================
# 1           212.529           212.514     1.11e-09    4.18e-10    0.15        787         0.100       1(0.000741)
# 2           212.515           212.515     3.58e-10    1.36e-10    0.000262    0.014       0.100       1(4.67e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 3.60  ======================
# 1           197.147           197.132     5.2e-10     9.81e-11    0.151       803         0.100       1(0.000657)
# 2           197.133           197.133     3.06e-09    7.5e-10     0.000191    0.014       0.100       1(3.99e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 3.70  ======================
# 1           180.659           180.644     2.05e-09    6.99e-10    0.151       819         0.100       1(0.000582)
# 2           180.645           180.645     2.53e-09    9.85e-10    0.000144    0.0141      0.100       1(3.38e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 3.80  ======================
# 1           165.211           165.196     2.59e-09    1.87e-09    0.152       835         0.100       1(0.000509)
# 2           165.197           165.197     9.4e-10     1.46e-09    0.000113    0.0144      0.100       1(2.84e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 3.90  ======================
# 1           143.835           143.820     5.23e-10    1.08e-09    0.152       856         0.100       1(0.000428)
# 2           143.820           143.820     1.35e-09    1.11e-09    9.04e-05    0.0147      0.100       1(2.38e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 4.00  ======================
# 1           124.119           124.104     3.67e-10    8.9e-14     0.153       876         0.100       1(0.000332)
# 2           124.104           124.104     2.38e-10    3.58e-14    7.5e-05     0.015       0.100       1(1.95e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 4.10  ======================
# 1           108.018           108.003     3.2e-10     4.61e-14    0.153       892         0.100       1(0.000201)
# 2           108.003           108.003     3.19e-10    1.84e-13    6.38e-05    0.0153      0.100       1(1.57e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 4.20  ======================
# 1           95.850            95.835      1.18e-11    4.45e-14    0.153       904         0.100       1(1.44e-05)
# 2           95.835            95.835      1.2e-11     4.33e-14    5.54e-05    0.0157      0.100       1(1.18e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 4.30  ======================
# 1           87.057            87.042      1.15e-11    2.54e-14    0.154       913         0.100       1(0.000251)
# 2           87.041            87.041      7.49e-12    1.83e-14    5.01e-05    0.0161      0.100       1(7.8e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 4.40  ======================
# 1           80.898            80.883      4.82e-10    3.93e-14    0.155       919         0.100       1(0.000633)
# 2           80.882            80.882      6.71e-10    1.4e-13     4.93e-05    0.0163      0.100       1(3.18e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 4.50  ======================
# 1           76.723            76.707      2.79e-10    8.61e-14    0.159       923         0.100       0(0.00119)
# 2           76.707            76.707      3.21e-10    1.19e-13    5.8e-05     0.0163      0.100       1(3.23e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 4.60  ======================
# 1           74.037            74.021      1.01e-11    2.77e-14    0.166       926         0.100       0(0.00188)
# 2           74.022            74.022      9.61e-12    2.47e-14    8.33e-05    0.0156      0.100       1(9.27e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 4.70  ======================
# 1           72.470            72.453      2.06e-10    1.93e-14    0.176       928         0.100       0(0.0026)
# 2           72.456            72.456      2.56e-10    1.79e-14    0.000127    0.0141      0.100       1(1.62e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 4.80  ======================
# 1           71.712            71.693      2.54e-10    4.5e-13     0.186       928         0.100       0(0.00318)
# 2           71.700            71.700      2.32e-10    4.13e-13    0.00018     0.0118      0.100       1(2.22e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 4.90  ======================
# 1           71.512            71.493      4.11e-10    1.4e-12     0.194       928         0.100       0(0.0036)
# 2           71.503            71.503      4.59e-10    1.76e-12    0.000229    0.00929     0.100       1(2.67e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 5.00  ======================
# 1           71.685            71.665      3.58e-10    9.61e-14    0.2         928         0.100       0(0.00391)
# 2           71.678            71.678      1.81e-10    6.25e-13    0.000272    0.00693     0.100       1(3e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 5.10  ======================
# 1           72.098            72.077      2.19e-10    1.34e-12    0.204       928         0.100       0(0.00412)
# 2           72.093            72.093      3.48e-10    1.52e-13    0.000306    0.0049      0.100       1(3.22e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 5.20  ======================
# 1           72.661            72.640      4.21e-10    7.75e-14    0.207       927         0.100       0(0.00428)
# 2           72.657            72.657      4.14e-10    6.43e-14    0.000332    0.00327     0.100       1(3.37e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 5.30  ======================
# 1           72.127            72.111      1.95e-10    2.48e-13    0.157       928         0.100       0(0.00321)
# 2           72.127            72.127      1.54e-10    5.28e-13    0.000238    0.000233    0.100       1(2.21e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 5.40  ======================
# 1           70.025            70.016      3.9e-10     2.47e-13    0.0842      930         0.100       0(0.00168)
# 2           70.025            70.025      2.33e-10    1.43e-13    0.000113    -0.000808   0.100       1(8.81e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 5.50  ======================
# 1           67.091            67.087      1.65e-10    1.25e-13    0.0454      933         0.100       1(0.000884)
# 2           67.092            67.092      1.92e-10    2.72e-13    5.52e-05    -0.000501   0.100       1(3.7e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 5.60  ======================
# 1           63.714            63.712      2.08e-10    5.11e-13    0.0245      936         0.100       1(0.000471)
# 2           63.714            63.714      2.16e-10    1.18e-12    2.77e-05    -0.000184   0.100       1(1.59e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 5.70  ======================
# 1           60.100            60.098      1.73e-10    1.87e-13    0.0133      940         0.100       1(0.000253)
# 2           60.100            60.100      1.66e-10    1.66e-13    1.43e-05    -3.39e-05   0.100       1(6.87e-08)
# SUCCEESS: virtual control and trust region < tol
# t curr: 5.80  ======================
# 1           56.357            56.356      3.88e-10    2.47e-12    0.00725     944         0.100       1(0.000136)
# 2           56.357            56.357      3.67e-10    1.81e-12    7.57e-06    1.12e-05    0.100       1(3.29e-08)
# SUCCEESS: virtual control and trust region < tol
# t curr: 5.90  ======================
# 1           52.545            52.545      1.86e-10    1.5e-12     0.00397     947         0.100       1(7.35e-05)
# 2           52.545            52.545      1.68e-10    8.29e-13    4.13e-06    1.29e-05    0.100       1(1.91e-08)
# SUCCEESS: virtual control and trust region < tol
# t curr: 6.00  ======================
# 1           48.696            48.695      1.01e-10    2.15e-14    0.00219     951         0.100       1(3.97e-05)
# 2           48.696            48.696      3.73e-10    1.45e-12    2.33e-06    2.34e-06    0.100       1(1.09e-08)
# SUCCEESS: virtual control and trust region < tol
# t curr: 6.10  ======================
# 1           44.823            44.823      1.24e-10    3.05e-14    0.00122     955         0.100       1(2.14e-05)
# 2           44.823            44.823      2.43e-10    7.83e-13    1.35e-06    -7.51e-06   0.100       1(6.14e-09)
# SUCCEESS: virtual control and trust region < tol
# t curr: 6.20  ======================
# 1           40.931            40.931      2.13e-10    2.35e-13    0.000697    959         0.100       1(1.15e-05)
# SUCCEESS: virtual control and trust region < tol
# t curr: 6.30  ======================
# 1           37.020            37.020      1.39e-10    4.75e-14    0.000412    963         0.100       1(6.17e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 6.40  ======================
# 1           33.088            33.087      8.65e-11    7.25e-14    0.000253    967         0.100       1(3.32e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 6.50  ======================
# 1           29.139            29.139      9.47e-11    7.88e-14    0.000167    971         0.100       1(1.77e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 6.60  ======================
# 1           25.205            25.205      3.56e-10    9.16e-14    0.00012     975         0.100       1(9.44e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 6.70  ======================
# 1           21.341            21.341      3.06e-10    2.71e-13    9.4e-05     979         0.100       1(5e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 6.80  ======================
# 1           17.619            17.619      9.36e-11    8.04e-16    7.74e-05    982         0.100       1(3.2e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 6.90  ======================
# 1           14.115            14.115      2.21e-10    7.58e-14    6.38e-05    986         0.100       1(2.97e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 7.00  ======================
# 1           10.917            10.917      7.77e-11    3.09e-14    4.93e-05    989         0.100       1(2.43e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 7.10  ======================
# 1           8.103             8.103       4.71e-11    4.86e-15    3.42e-05    992         0.100       1(1.73e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 7.20  ======================
# 1           5.706             5.706       1.21e-10    7.28e-14    2.11e-05    994         0.100       1(1.1e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 7.30  ======================
# 1           3.634             3.634       5.14e-11    1.34e-14    1.2e-05     996         0.100       1(6.5e-08)
# SUCCEESS: virtual control and trust region < tol
# t curr: 7.40  ======================
# 1           2.126             2.126       5.29e-11    1.41e-15    6.58e-06    998         0.100       1(3.67e-08)
# SUCCEESS: virtual control and trust region < tol
# t curr: 7.50  ======================
# 1           1.323             1.323       3.22e-11    1.4e-15     3.53e-06    999         0.100       1(2.01e-08)
# SUCCEESS: virtual control and trust region < tol
# t curr: 7.60  ======================
# 1           0.895             0.895       1.06e-11    5.49e-16    1.86e-06    999         0.100       1(1.08e-08)
# SUCCEESS: virtual control and trust region < tol
# t curr: 7.70  ======================
# 1           0.668             0.668       8.31e-12    9.74e-16    9.78e-07    999         0.100       1(5.75e-09)
# SUCCEESS: virtual control and trust region < tol
# t curr: 7.80  ======================
# 1           0.547             0.547       6.86e-12    6.26e-16    5.11e-07    999         0.100       1(3.02e-09)
# SUCCEESS: virtual control and trust region < tol
# t curr: 7.90  ======================
# 1           0.483             0.483       1.51e-11    2.72e-15    2.67e-07    1e+03       0.100       1(1.57e-09)
# SUCCEESS: virtual control and trust region < tol

# %%
plt.figure(figsize=(15,10))
fS = 18
plt.subplot(231)
plt.plot(xbar[:,0], xbar[:,1],'--', linewidth=2.0)
plt.plot(x_save[:,0], x_save[:,1],'-', linewidth=2.0)
plt.plot(xf[0],xf[1],"o",label='goal')
plt.gca().set_aspect('equal', adjustable='box')
plt.axis([-6, 6, -6, 6])
plt.xlabel('X (m)', fontsize = fS)
plt.ylabel('Y (m)', fontsize = fS)
plt.subplot(232)
plt.plot(t_index, xbar[:,0],'--', linewidth=2.0)
plt.plot(t_save, x_save[:,0],'-',linewidth=2.0)
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('x1 (m)', fontsize = fS)
plt.subplot(233)
plt.plot(t_index, xbar[:,1],'--',linewidth=2.0)
plt.plot(t_save, x_save[:,1],'-',linewidth=2.0)
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('x2 (m)', fontsize = fS)
plt.subplot(234)
plt.plot(t_index, np.rad2deg(xbar[:,2]),'--',linewidth=2.0)
plt.plot(t_save, np.rad2deg(x_save[:,2]),'-',linewidth=2.0)
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('x3 (rad)', fontsize = fS)
plt.subplot(235)
plt.plot(t_index, ubar[:,0],'--',linewidth=2.0)
plt.step(t_save,[*u_save[:,0],u_save[-1,0]],label='zoh',where='post')
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('v (m/s)', fontsize = fS)
plt.subplot(236)
plt.plot(t_index, np.rad2deg(ubar[:,1]),'--',linewidth=2.0)
plt.step(t_save,np.rad2deg([*u_save[:,1],u_save[-1,1]]),label='zoh',where='post')
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('w (rad/s)', fontsize = fS)
plt.show()

# %% [markdown]
# ## make a video

# %%
from matplotlib.patches import Rectangle,Ellipse
import imageio.v2 as imageio
import os

# %%
filenames = []
t_curr = 0
for idx in range(Nsim+1) :
    fig = plt.figure(figsize=(10,10))
    ax = fig.add_subplot(111)
    fS = 15
    plt.plot(xbar[:,0], xbar[:,1],'--', linewidth=2.0,label='nominal trajectory')
    plt.plot(x_save[:idx+1,0], x_save[:idx+1,1],'-', linewidth=2.0,label='result trajectory')
    if idx < Nsim :
        plt.plot(x_traj[idx][:,0], x_traj[idx][:,1],'-',color='tab:green', linewidth=2.0,label='future prediction')
        plt.plot(x_traj[idx][0,0], x_traj[idx][0,1],'o',color='tab:green', linewidth=2.0)
#     for ce,H in zip(cobs,Hobs) :
    if idx < Nsim :
        cmpc = c_traj[idx]
        Hmpc = H_traj[idx]
    for idx_obstacle, (ce,H) in enumerate(zip(cmpc,Hmpc)) :
        rx = 1/H[0,0]
        ry = 1/H[1,1]
        if idx_obstacle == 0:
            circle1 = Ellipse((ce[0],ce[1]),rx*2,ry*2,color='tab:red',alpha=1.0,fill=True)
        else :
            circle1 = Ellipse((ce[0],ce[1]),rx*2,ry*2,color='tab:pink',alpha=0.2*np.exp(-idx_obstacle/10),fill=True)
        ax.add_patch(circle1)
    
    plt.gca().set_aspect('equal', adjustable='box')
    plt.axis([-6, 6, -6, 6])
    plt.xlabel('X (m)', fontsize = fS)
    plt.ylabel('Y (m)', fontsize = fS)
    plt.legend(fontsize=fS)

    filename = '../images/{:d}.png'.format(idx)
    plt.savefig(filename)
    filenames.append(filename)
    plt.close()
    t_curr += dt

# %%
img_name = 'MPC_moving_obstacle_' + FRS_obstacle
with imageio.get_writer('../images/'+img_name+'.gif', mode='I') as writer:
        for filename in filenames:
            image = imageio.imread(filename)
            writer.append_data(image)

# %%
img_name = 'video_MPC_moving_obstacle_' + FRS_obstacle
with imageio.get_writer('../images/'+img_name+'.mov', fps=int(1/dt)) as writer:
    for filename in filenames:
        image = imageio.imread(filename)
        writer.append_data(image)

# %%
for filename in set(filenames):
    os.remove(filename)

# %%
filenames = []
t_curr = 0
for idx in range(Nsim+1) :
    idx = 0
    fig = plt.figure(figsize=(10,10))
    ax = fig.add_subplot(111)
    fS = 15
    plt.plot(xbar[:,0], xbar[:,1],'--', linewidth=2.0,label='nominal trajectory')
    plt.plot(x_save[:idx+1,0], x_save[:idx+1,1],'-', linewidth=2.0,label='result trajectory')
    if idx < Nsim :
        plt.plot(x_traj[idx][:,0], x_traj[idx][:,1],'-',color='tab:green', linewidth=2.0,label='future prediction')
        plt.plot(x_traj[idx][0,0], x_traj[idx][0,1],'o',color='tab:green', linewidth=2.0)
#     for ce,H in zip(cobs,Hobs) :
    if idx < Nsim :
        cmpc = c_traj[idx]
        Hmpc = H_traj[idx]
    for idx_obstacle, (ce,H) in enumerate(zip(cmpc,Hmpc)) :
        rx = 1/H[0,0]
        ry = 1/H[1,1]
        if idx_obstacle == 0:
            circle1 = Ellipse((ce[0],ce[1]),rx*2,ry*2,color='tab:red',alpha=1.0,fill=True)
        else :
            circle1 = Ellipse((ce[0],ce[1]),rx*2,ry*2,color='tab:pink',alpha=0.2*np.exp(-idx_obstacle/10),fill=True)
        ax.add_patch(circle1)
    
    plt.gca().set_aspect('equal', adjustable='box')
    plt.axis([-6, 6, -6, 6])
    plt.xlabel('X (m)', fontsize = fS)
    plt.ylabel('Y (m)', fontsize = fS)
    plt.legend(fontsize=fS)

    filename = '../images/{:d}.png'.format(idx)
    plt.savefig(filename)
    filenames.append(filename)
    plt.close()
    t_curr += dt
