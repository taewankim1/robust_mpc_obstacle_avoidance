# %%
import matplotlib.pyplot as plt
# %matplotlib inline  
# %load_ext autoreload
# %autoreload 2
import numpy as np
import time
import random
def print_np(x):
    print ("Type is %s" % (type(x)))
    print ("Shape is %s" % (x.shape,))
#     print ("Values are: \n%s" % (x))

# %%
import sys
# sys.path.append('../')
sys.path.append('../')
sys.path.append('../model')
sys.path.append('../cost')
sys.path.append('../constraints')
import UnicycleModel
import FinaltimeFreeCost
import UnicycleCost
import UnicycleConstraints
from scipy.integrate import solve_ivp
from PTR_tf_free import PTR_tf_free
from PTR_in_MPC import PTR_in_MPC
from Scaling import TrajectoryScaling
from scipy.interpolate import interp1d
from scipy.integrate import solve_ivp
# Out:
# (CVXPY) Sep 05 05:39:31 PM: Encountered unexpected exception importing solver SCS:
# ImportError("dlopen(/opt/anaconda3/envs/py309/lib/python3.9/site-packages/_scs_direct.cpython-39-darwin.so, 0x0002): Library not loaded: @rpath/liblapack.3.dylib\n  Referenced from: /opt/anaconda3/envs/py309/lib/python3.9/site-packages/_scs_direct.cpython-39-darwin.so\n  Reason: tried: '/opt/anaconda3/envs/py309/lib/python3.9/site-packages/../../liblapack.3.dylib' (no such file), '/opt/anaconda3/envs/py309/lib/python3.9/site-packages/../../liblapack.3.dylib' (no such file), '/opt/anaconda3/envs/py309/bin/../lib/liblapack.3.dylib' (no such file), '/opt/anaconda3/envs/py309/bin/../lib/liblapack.3.dylib' (no such file), '/usr/local/lib/liblapack.3.dylib' (no such file), '/usr/lib/liblapack.3.dylib' (no such file)")

# %% [markdown]
# ## Nominal trajectory generation

# %%
ix = 3
iu = 2
ih = 2
N = 50
tf = 10
delT = tf/N
max_iter = 30

# %%
x_max = np.array([5,5,np.deg2rad(90)])
x_min = np.zeros(ix)

u_max = np.array([2,np.deg2rad(90)]) 
u_min = np.array([0,0])


myScaling = TrajectoryScaling(x_min,x_max,u_min,u_max,tf)
Sx,iSx,sx,Su,iSu,su = myScaling.get_scaling()

# %%
myModel = UnicycleModel.unicycle('Hello',ix,iu,'numeric_central')
myCost = FinaltimeFreeCost.Finaltime('Hello',ix,iu,N)
myConst = UnicycleConstraints.UnicycleConstraints('Hello',ix,iu)

# %%
xi = np.zeros(3)
xi[0] = -5.0
xi[1] = -5.0 
xi[2] = 0

xf = np.zeros(3)
xf[0] = 5.0
xf[1] = 5.0
xf[2] = 0


x0 = np.zeros((N+1,ix))
for i in range(N+1) :
    x0[i] = (N-i)/N * xi + i/N * xf
    
u0 = np.zeros((N+1,iu))
ui = np.array([2,0])
uf = np.array([2,0])

for i in range(N+1) :
    u0[i] = (N-i)/N * ui + i/N * uf

# %%
TrajOpt = PTR_tf_free('unicycle',N,tf,max_iter,myModel,myCost,myConst,myScaling,
          type_discretization="foh",w_c=1,w_vc=1e3,w_tr=1e-1,w_rate=0,tol_vc=1e-6,tol_tr=1e-3)
xfwd,ufwd,xbar,ubar,tfbar,total_num_iter,flag_boundary,l,l_vc,l_tr,x_traj,u_traj,T_traj  = TrajOpt.run(x0,u0,xi,xf)
print("final time {:}".format(tfbar))
# Out:
# iteration   total_cost        cost        ||vc||     ||tr||       reduction   w_tr        dynamics
# 1           5.696             5.000       1.95e-12    6.96        4.3         0.100       0(0.128)
# 2           7.734             6.976       3.95e-12    7.57        -2.04       0.100       0(0.0652)
# 3           7.324             7.132       3.9e-13     1.92        0.409       0.100       0(0.0153)
# 4           7.256             7.253       1.06e-11    0.0302      0.0685      0.100       1(0.000274)
# 5           7.252             7.251       8.5e-12     0.0098      0.00348     0.100       1(2.3e-05)
# 6           7.251             7.250       1.46e-12    0.00635     0.00153     0.100       1(1.8e-05)
# 7           7.250             7.250       1.01e-12    0.00157     0.000715    0.100       1(3.7e-06)
# 8           7.250             7.250       8.91e-13    0.00109     0.000236    0.100       1(1.6e-06)
# 9           7.250             7.250       7.81e-13    0.000881    0.000185    0.100       1(1.31e-06)
# SUCCEESS: virtual control and trust region < tol
# final time 7.2495603290843835

# %%
t_index = np.array([i for i in range(N+1)]) / N * tfbar

# %%
tfbar
# Out:
# 7.2495603290843835

# %%
plt.figure(figsize=(15,10))
fS = 18
plt.subplot(231)
plt.plot(xbar[:,0], xbar[:,1],'-', linewidth=2.0)
plt.plot(xf[0],xf[1],"o",label='goal')
plt.gca().set_aspect('equal', adjustable='box')
plt.axis([-6, 6, -6, 6])
plt.xlabel('X (m)', fontsize = fS)
plt.ylabel('Y (m)', fontsize = fS)
plt.subplot(232)
plt.plot(t_index, xbar[:,0],'-', linewidth=2.0)
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('x (m)', fontsize = fS)
plt.subplot(233)
plt.plot(t_index, xbar[:,1],'-',linewidth=2.0)
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('y (m)', fontsize = fS)
plt.subplot(234)
plt.plot(t_index, np.rad2deg(xbar[:,2]),'-',linewidth=2.0)
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('$\Theta$ (rad)', fontsize = fS)
plt.subplot(235)
plt.plot(t_index, ubar[:,0],'-',linewidth=2.0)
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('v (m/s)', fontsize = fS)
plt.ylim([0,3])
plt.subplot(236)
plt.plot(t_index, np.rad2deg(ubar[:,1]),'-',linewidth=2.0)
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('w (rad/s)', fontsize = fS)
plt.show()

# %% [markdown]
# ## Set MPC controller with static obstacle

# %% [markdown]
# ### nominal trajectory is given as xbar, ubar

# %%
fun_unom = interp1d(t_index,ubar,axis=0)
def get_traj_teval(t_eval) :
    if len(t_eval) == 0 :
        return [],[]
    assert np.max(t_eval) <= t_index[-1]
    def dfdt(t,x) :
        u = fun_unom(t)
        return np.squeeze(myModel.forward(x,u))

    sol = solve_ivp(dfdt,(t_index[0],t_index[-1]),xi,t_eval=t_eval,rtol=1e-12,atol=1e-12)
    return sol.y.T,fun_unom(t_eval)

def forward_dt(dt,xi,u) :
    def dfdt(t,x) :
        return np.squeeze(myModel.forward(x,u))
    sol = solve_ivp(dfdt,(0,dt),xi,rtol=1e-12,atol=1e-12)
    return sol
def get_H_obs(rx,ry) :
    return np.diag([1/rx,1/ry])

# %%
tbar = np.array([i for i in range(N+1)]) / N * tfbar
tfsim = 8
horizon = 2
dt = 0.1
Nsim = int(tfsim / dt)
Nmpc =  int(horizon / dt) # N+1 is total discretization points for state
print("Nmpc: {:}".format(Nmpc))

xi_mpc = np.zeros(3)
xi_mpc[0] = -5.0
xi_mpc[1] = -4.0 
xi_mpc[2] = 0
# Out:
# Nmpc: 20

# %%
# cost and constraint / model is identical
MPC_Cost = UnicycleCost.unicycleMPC('Hello',ix,iu,Nmpc)
MPC_Const = UnicycleConstraints.unicycleMPC('Hello',ix,iu)

# # define optimal control
MPC_controller = PTR_in_MPC('unicycle',Nmpc,horizon,max_iter,myModel,MPC_Cost,MPC_Const,myScaling,
          type_discretization="zoh",w_c=1,w_vc=1e3,w_bf=1e3,w_tr=1e-1,w_rate=0,
                            tol_vc=1e-6,tol_bf=1e-3,tol_tr=1e-3)

# %%
t_curr = 0
x_curr = np.copy(xi_mpc)

t_save,x_save,u_save = [],[],[]
t_save.append(t_curr)
x_save.append(xi_mpc)

t_traj,x_traj,u_traj = [],[],[]
c_traj,H_traj = [],[]


for _ in range(Nsim) :
    print("t curr: {:.2f}  ======================".format(t_curr))
    # estimating nominal trajectory within horizon
    t_horizon = np.array([t_curr + dt*i for i in range(Nmpc+1)])
    t_eval = t_horizon[t_horizon <= tfbar]
    t_end = t_horizon[t_horizon > tfbar]
    xfwd,ufwd = get_traj_teval(t_eval)
    for _ in t_end :
        if len(xfwd) == 0 :
            xfwd = xbar[-1]
            ufwd = ubar[-1]
        else :
            xfwd = np.vstack((xfwd,xbar[-1]))
            ufwd = np.vstack((ufwd,ubar[-1]))


    # estimate the model of non-cooperative agent
    cobs,Hobs = [],[]
    # static obstacle
    c = [0,1]
    H = get_H_obs(2,2)
    for i in range(Nmpc+1) :
        cobs.append(c)
        Hobs.append(H)
        
    
    # solve optimal control
    # initiall condition
    if t_curr == 0 :
        x0 = xfwd
        u0 = ufwd
    else :
        x0 = np.copy(xmpc)
        x0[:Nmpc] = xmpc[1:]
        u0 = np.copy(umpc)
        u0[:Nmpc] = umpc[1:]


    _,_,xmpc,umpc,num_iter,flag_boundary,l,l_vc,l_tr,_,_,_  = MPC_controller.run(x0,u0,x_curr,xfwd,ufwd,cobs,Hobs)

    # apply input to the system (integration)
    sol = forward_dt(dt,x_curr,umpc[0])
    t_curr += dt
    x_curr = sol.y.T[-1]

    # save
    t_save.append(t_curr)
    x_save.append(x_curr)
    u_save.append(umpc[0])

    t_traj.append(t_horizon)
    x_traj.append(xmpc)
    u_traj.append(umpc)
#     break

x_save = np.array(x_save)
u_save = np.array(u_save)
# Out:
# t curr: 0.00  ======================
# iteration   total_cost        cost        ||vc||     ||bf||     ||tr||       reduction   w_tr        bounary
# 1           124.495           123.883     3.88e-10    2.15e-13    6.12        876         0.100       0(0.0302)
# 2           134.017           133.982     5.11e-10    4.68e-13    0.355       -9.52       0.100       0(0.00112)
# 3           133.821           133.813     3.04e-10    8.24e-13    0.0828      0.196       0.100       1(0.000326)
# 4           133.848           133.847     1.35e-10    5.37e-14    0.00689     -0.0266     0.100       1(6.31e-05)
# 5           133.853           133.853     1.29e-10    5.38e-14    0.00117     -0.00528    0.100       1(7.1e-06)
# 6           133.854           133.854     1.42e-10    6.55e-14    0.000114    -0.000811   0.100       1(1.24e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 0.10  ======================
# 1           122.312           122.297     1.76e-10    4.84e-14    0.147       878         0.100       1(0.000324)
# 2           122.298           122.298     1.79e-10    5.98e-14    8.78e-05    0.0145      0.100       1(2.32e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 0.20  ======================
# 1           110.829           110.814     3.93e-10    2.75e-13    0.149       889         0.100       1(0.000264)
# 2           110.814           110.814     3.8e-10     7.56e-13    7.23e-05    0.0148      0.100       1(1.91e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 0.30  ======================
# 1           100.258           100.243     6.73e-11    1.22e-13    0.15        900         0.100       1(0.000214)
# 2           100.243           100.243     4.97e-10    6.26e-13    6.26e-05    0.015       0.100       1(1.56e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 0.40  ======================
# 1           91.170            91.155      3.23e-10    2.56e-13    0.151       909         0.100       1(0.000176)
# 2           91.155            91.155      2.59e-10    6.14e-14    5.67e-05    0.0152      0.100       1(1.27e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 0.50  ======================
# 1           83.769            83.754      1.44e-10    8.54e-14    0.152       916         0.100       1(0.000146)
# 2           83.754            83.754      1.57e-10    2.25e-14    5.3e-05     0.0153      0.100       1(1.03e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 0.60  ======================
# 1           78.027            78.011      2.15e-10    3.15e-13    0.153       922         0.100       1(0.000124)
# 2           78.011            78.011      3.09e-10    8.81e-14    5.07e-05    0.0154      0.100       1(8.47e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 0.70  ======================
# 1           73.780            73.764      3.81e-10    1.65e-12    0.153       926         0.100       1(0.000107)
# 2           73.764            73.764      2.71e-10    7.17e-14    4.92e-05    0.0155      0.100       1(6.95e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 0.80  ======================
# 1           70.833            70.817      3.4e-10     3.2e-12     0.154       929         0.100       1(9.3e-05)
# 2           70.817            70.817      1.26e-10    8.29e-14    4.82e-05    0.0156      0.100       1(5.72e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 0.90  ======================
# 1           68.957            68.942      3.49e-10    3.85e-12    0.154       931         0.100       1(8.17e-05)
# 2           68.941            68.941      3.18e-10    7.14e-13    4.75e-05    0.0156      0.100       1(4.72e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 1.00  ======================
# 1           67.917            67.901      2.24e-10    3.65e-13    0.154       932         0.100       1(7.21e-05)
# 2           67.901            67.901      2.9e-10     5.72e-13    4.7e-05     0.0156      0.100       1(3.9e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 1.10  ======================
# 1           67.461            67.445      1.8e-10     4.01e-13    0.154       933         0.100       1(6.37e-05)
# 2           67.445            67.445      3.49e-10    3.58e-12    4.67e-05    0.0156      0.100       1(3.24e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 1.20  ======================
# 1           67.376            67.360      2.37e-10    9.05e-13    0.154       933         0.100       1(5.59e-05)
# 2           67.360            67.360      6.78e-11    8e-14       4.66e-05    0.0157      0.100       1(2.69e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 1.30  ======================
# 1           67.501            67.485      9.73e-11    1.72e-13    0.154       932         0.100       1(4.87e-05)
# 2           67.485            67.485      1.34e-10    3.15e-13    4.64e-05    0.0157      0.100       1(2.22e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 1.40  ======================
# 1           68.360            68.358      6.53e-11    9.72e-12    0.02        932         0.100       1(9.79e-05)
# 2           68.355            68.355      2.81e-11    4.1e-11     1.91e-05    0.00499     0.100       1(3.72e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 1.50  ======================
# 1           72.110            72.110      5.31e-12    9.08e-12    0.00223     928         0.100       1(1.81e-05)
# 2           72.109            72.109      2.1e-12     2.79e-11    1.41e-05    0.00154     0.100       1(6.19e-08)
# SUCCEESS: virtual control and trust region < tol
# t curr: 1.60  ======================
# 1           79.548            79.547      4.94e-10    3.19e-11    0.00316     920         0.100       1(2e-05)
# 2           79.541            79.541      5.14e-10    3.67e-11    3.52e-05    0.00705     0.100       1(3.66e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 1.70  ======================
# 1           91.345            91.345      3.3e-10     6.27e-11    0.00424     909         0.100       1(2.56e-05)
# 2           91.329            91.329      3.22e-10    5.52e-11    9.61e-05    0.0164      0.100       1(1.13e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 1.80  ======================
# 1           108.171           108.171     9.84e-11    2.81e-10    0.00555     892         0.100       1(3.42e-05)
# 2           108.139           108.139     8.24e-11    2.35e-10    0.000234    0.0318      0.100       1(2.8e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 1.90  ======================
# 1           130.670           130.670     5.07e-10    1.02e-10    0.00729     869         0.100       1(4.7e-05)
# 2           130.614           130.614     5.67e-10    1.85e-10    0.000521    0.0566      0.100       1(6.25e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 2.00  ======================
# 1           159.444           159.443     4.84e-10    3.76e-11    0.00978     841         0.100       1(6.71e-05)
# 2           159.347           159.347     3.66e-10    4.59e-11    0.0011      0.0972      0.100       1(1.33e-05)
# 3           159.336           159.336     3.85e-10    2.17e-10    0.000148    0.011       0.100       1(2.12e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 2.10  ======================
# 1           195.007           195.006     1.83e-10    5.34e-10    0.012       805         0.100       1(8.4e-05)
# 2           194.860           194.860     1.57e-10    8.55e-11    0.002       0.147       0.100       1(2.46e-05)
# 3           194.835           194.835     1.53e-10    6.17e-11    0.000407    0.0251      0.100       1(5.83e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 2.20  ======================
# 1           237.786           237.784     1.88e-10    1.88e-10    0.0163      762         0.100       1(0.000119)
# 2           237.537           237.536     3.41e-10    1.03e-10    0.00398     0.249       0.100       1(4.58e-05)
# 3           237.471           237.471     1.17e-10    2.66e-11    0.00125     0.0653      0.100       1(1.62e-05)
# 4           237.453           237.453     2.5e-10     9.06e-11    0.000406    0.0189      0.100       1(5.73e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 2.30  ======================
# 1           287.867           287.865     3.7e-10     1.87e-10    0.0221      712         0.100       1(0.000155)
# 2           287.444           287.444     2.84e-10    1.47e-10    0.00809     0.423       0.100       1(9.66e-05)
# 3           287.275           287.275     5.09e-10    1.18e-10    0.00393     0.169       0.100       1(5.56e-05)
# 4           287.200           287.200     3.32e-10    1.04e-10    0.00197     0.0752      0.100       1(2.95e-05)
# 5           287.165           287.165     3.63e-10    2.24e-10    0.000996    0.0354      0.100       1(1.55e-05)
# SUCCEESS: virtual control and trust region < tol
# t curr: 2.40  ======================
# 1           344.653           344.650     8.31e-10    1.08e-09    0.0312      655         0.100       1(0.000268)
# 2           343.837           343.835     8.63e-10    1.5e-09     0.0184      0.817       0.100       1(0.000246)
# 3           343.337           343.335     2.31e-10    4.18e-10    0.0136      0.5         0.100       1(0.00021)
# 4           342.998           342.997     6.83e-11    8.36e-11    0.0103      0.339       0.100       1(0.000171)
# 5           342.752           342.751     2.23e-10    7.07e-11    0.00775     0.246       0.100       1(0.000123)
# 6           342.549           342.549     4.46e-10    8.7e-11     0.00691     0.202       0.100       1(0.000107)
# 7           342.369           342.368     5.06e-10    1.97e-10    0.00662     0.18        0.100       1(0.000104)
# 8           342.201           342.200     4.79e-10    1.51e-10    0.00652     0.168       0.100       1(0.00011)
# 9           342.039           342.038     3.75e-10    1.52e-10    0.00651     0.162       0.100       1(0.000114)
# 10          341.879           341.878     5.28e-10    3.2e-10     0.00659     0.16        0.100       1(0.000117)
# 11          341.717           341.716     3.48e-11    1.02e-10    0.00675     0.161       0.100       1(0.000122)
# 12          341.552           341.551     2.59e-11    8.54e-11    0.00698     0.165       0.100       1(0.000127)
# 13          341.381           341.380     2.05e-11    7.53e-11    0.00726     0.171       0.100       1(0.000132)
# 14          341.202           341.201     1.55e-11    6.68e-11    0.00759     0.178       0.100       1(0.000138)
# 15          341.016           341.015     3.13e-11    3.17e-11    0.00786     0.187       0.100       1(0.000143)
# 16          340.808           340.807     8.04e-11    4.04e-11    0.00902     0.208       0.100       1(0.000132)
# 17          340.538           340.536     5.7e-11     2.45e-11    0.0124      0.27        0.100       1(0.000197)
# 18          340.173           340.171     4.55e-11    1.81e-11    0.0176      0.365       0.100       1(0.000306)
# 19          339.676           339.673     4.47e-11    1.77e-11    0.0249      0.497       0.100       1(0.000441)
# 20          339.002           338.999     5.37e-11    2.24e-11    0.0341      0.673       0.100       1(0.000601)
# 21          338.111           338.107     1.11e-10    1.42e-10    0.0448      0.891       0.100       1(0.000777)
# 22          336.871           336.864     2.38e-10    1.07e-10    0.0649      1.24        0.100       1(0.000848)
# 23          334.848           334.837     6.74e-10    1.97e-09    0.112       2.02        0.100       0(0.00176)
# 24          331.645           331.627     5.02e-10    1.99e-10    0.175       3.2         0.100       0(0.00274)
# 25          326.283           326.251     3.3e-10     4.58e-10    0.321       5.36        0.100       0(0.00414)
# 26          317.369           317.314     9.14e-11    1.44e-10    0.552       8.91        0.100       0(0.00392)
# 27          307.871           307.790     4.46e-10    5.57e-10    0.813       9.5         0.100       0(0.00154)
# 28          300.884           300.828     1.21e-08    1.59e-08    0.56        6.99        0.100       0(0.00466)
# 29          299.830           299.823     2.35e-09    5.98e-09    0.0617      1.05        0.100       1(0.000323)
# 30          299.692           299.691     9.13e-09    2.44e-08    0.00367     0.138       0.100       1(6.1e-05)
# NOT ENOUGH : reached to max iteration
# t curr: 2.50  ======================
# 1           321.883           321.858     2.46e-08    6.56e-08    0.251       678         0.100       0(0.00346)
# 2           320.771           320.769     3.18e-08    8.32e-08    0.0274      1.11        0.100       1(0.000218)
# 3           320.533           320.533     2.12e-08    5.62e-08    0.00479     0.238       0.100       1(5.47e-05)
# 4           320.471           320.470     1.07e-08    2.8e-08     0.00124     0.0628      0.100       1(7.71e-06)
# 5           320.452           320.452     3.34e-09    8.65e-09    0.000416    0.0185      0.100       1(1.85e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 2.60  ======================
# 1           339.071           339.046     5.22e-09    1.34e-08    0.251       661         0.100       0(0.00207)
# 2           338.142           338.139     1.4e-09     3.53e-09    0.0283      0.929       0.100       1(0.000225)
# 3           337.972           337.971     1.26e-09    3.11e-09    0.00452     0.171       0.100       1(3.19e-05)
# 4           337.932           337.932     1.85e-10    2.99e-10    0.00105     0.0392      0.100       1(8.25e-06)
# 5           337.921           337.921     1.81e-10    3.51e-10    0.000365    0.0111      0.100       1(1.27e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 2.70  ======================
# 1           352.692           352.667     3.05e-10    6e-10       0.248       647         0.100       0(0.00139)
# 2           351.937           351.935     7.12e-10    1.31e-09    0.0217      0.755       0.100       1(0.000137)
# 3           351.819           351.819     3.89e-09    8.3e-09     0.00286     0.118       0.100       1(1.96e-05)
# 4           351.798           351.797     3.26e-09    7.25e-09    0.000467    0.0218      0.100       1(4.32e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 2.80  ======================
# 1           362.884           362.861     1.79e-09    4.5e-09     0.234       637         0.100       1(0.000979)
# 2           362.289           362.287     2.26e-09    4.75e-09    0.0182      0.595       0.100       1(0.000135)
# 3           362.215           362.215     3.43e-09    7.88e-09    0.00245     0.0738      0.100       1(6.87e-06)
# 4           362.205           362.205     2.72e-09    6.34e-09    0.000432    0.0105      0.100       1(5.01e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 2.90  ======================
# 1           369.814           369.792     1.66e-09    3.9e-09     0.218       630         0.100       1(0.000772)
# 2           369.369           369.367     2.46e-09    5.39e-09    0.0138      0.445       0.100       1(0.000117)
# 3           369.325           369.324     2.72e-09    6.25e-09    0.00173     0.0441      0.100       1(4.55e-06)
# 4           369.320           369.320     2.8e-09     5.63e-09    0.000315    0.0044      0.100       1(3.24e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 3.00  ======================
# 1           373.647           373.626     1.12e-09    2.47e-09    0.202       626         0.100       0(0.00108)
# 2           373.319           373.318     6.45e-10    8.92e-10    0.0101      0.328       0.100       1(0.000102)
# 3           373.291           373.291     6.83e-10    1.11e-09    0.00139     0.0278      0.100       1(3.48e-06)
# 4           373.288           373.288     1.02e-09    2.19e-09    0.000228    0.00248     0.100       1(1.32e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 3.10  ======================
# 1           374.451           374.434     2.25e-09    4.96e-09    0.177       626         0.100       0(0.00133)
# 2           374.241           374.240     3.26e-09    7.22e-09    0.00655     0.21        0.100       1(6.15e-05)
# 3           374.230           374.230     2.71e-09    5.95e-09    0.000607    0.0112      0.100       1(2.94e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 3.20  ======================
# 1           372.352           372.336     2.13e-09    4.58e-09    0.159       628         0.100       0(0.0013)
# 2           372.201           372.201     1.07e-09    2.11e-09    0.00415     0.151       0.100       1(3.86e-05)
# 3           372.195           372.195     1.05e-09    2.13e-09    0.000354    0.00651     0.100       1(1.41e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 3.30  ======================
# 1           367.073           367.058     1.55e-09    3.52e-09    0.147       633         0.100       0(0.00131)
# 2           366.972           366.972     2.91e-09    6.7e-09     0.00297     0.101       0.100       1(2.38e-05)
# 3           366.969           366.969     3.67e-09    8.42e-09    0.000233    0.00298     0.100       1(9.75e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 3.40  ======================
# 1           358.256           358.242     2.28e-10    4.15e-10    0.139       642         0.100       0(0.00126)
# 2           358.189           358.188     2.28e-10    4.18e-10    0.00211     0.0671      0.100       1(1.54e-05)
# 3           358.187           358.187     2.16e-10    3.98e-10    0.000145    0.00122     0.100       1(6.24e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 3.50  ======================
# 1           345.504           345.491     3.06e-09    7.21e-09    0.136       654         0.100       0(0.00118)
# 2           345.459           345.459     2.42e-09    5.45e-09    0.00151     0.0453      0.100       1(1e-05)
# 3           345.458           345.458     8.34e-10    2.03e-09    8.49e-05    0.000382    0.100       1(3.78e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 3.60  ======================
# 1           328.793           328.780     4.35e-10    1.35e-09    0.135       671         0.100       0(0.00107)
# 2           328.761           328.761     4.07e-10    1.27e-09    0.00108     0.032       0.100       1(7.37e-06)
# 3           328.761           328.761     4.43e-10    1.36e-09    4.67e-05    6.73e-06    0.100       1(2.39e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 3.70  ======================
# 1           308.685           308.672     1.46e-09    3.72e-09    0.136       691         0.100       1(0.000948)
# 2           308.661           308.661     1.36e-09    3.47e-09    0.000779    0.0243      0.100       1(6.61e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 3.80  ======================
# 1           286.647           286.633     5.95e-09    1.24e-08    0.14        713         0.100       1(0.000856)
# 2           286.628           286.628     1.71e-08    3.51e-08    0.000601    0.0192      0.100       1(6.55e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 3.90  ======================
# 1           263.078           263.064     6.93e-09    3.14e-08    0.142       737         0.100       1(0.000755)
# 2           263.062           263.062     7.24e-09    3.23e-08    0.000432    0.0168      0.100       1(5.97e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 4.00  ======================
# 1           238.440           238.426     1.03e-09    3.85e-09    0.144       762         0.100       1(0.000686)
# 2           238.425           238.425     6.98e-10    3.23e-09    0.000312    0.0154      0.100       1(5.26e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 4.10  ======================
# 1           213.465           213.450     2.44e-10    2.85e-10    0.146       787         0.100       1(0.000667)
# 2           213.450           213.450     1.36e-09    2.46e-09    0.000232    0.0143      0.100       1(4.54e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 4.20  ======================
# 1           188.927           188.912     3.7e-10     6.98e-10    0.149       811         0.100       1(0.000721)
# 2           188.913           188.913     3.24e-09    7.26e-09    0.00018     0.0134      0.100       1(3.91e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 4.30  ======================
# 1           165.522           165.507     8.99e-10    5.02e-09    0.151       834         0.100       1(0.000869)
# 2           165.510           165.510     1e-09       5.19e-09    0.00015     0.0125      0.100       1(3.41e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 4.40  ======================
# 1           143.720           143.704     1.22e-09    2.29e-09    0.154       856         0.100       0(0.00115)
# 2           143.708           143.708     1.2e-09     2.29e-09    0.000138    0.0113      0.100       1(3.08e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 4.50  ======================
# 1           124.375           124.359     2.62e-10    7.2e-13     0.159       876         0.100       0(0.00161)
# 2           124.365           124.365     2.55e-10    6.96e-13    0.000146    0.0096      0.100       1(2.94e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 4.60  ======================
# 1           108.386           108.369     3.39e-10    7.65e-13    0.168       892         0.100       0(0.00222)
# 2           108.378           108.378     3.1e-10     4.84e-13    0.000174    0.00751     0.100       1(2.98e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 4.70  ======================
# 1           96.269            96.251      6.5e-10     1.36e-12    0.178       904         0.100       0(0.00287)
# 2           96.264            96.264      1.4e-10     6.15e-14    0.00022     0.00515     0.100       1(3.15e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 4.80  ======================
# 1           87.614            87.595      5.85e-10    5.64e-13    0.188       912         0.100       0(0.00339)
# 2           87.611            87.611      5.83e-10    5.58e-13    0.000267    0.00299     0.100       1(3.32e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 4.90  ======================
# 1           81.732            81.712      3.86e-10    4.46e-14    0.196       918         0.100       0(0.00376)
# 2           81.731            81.731      3.7e-10     3.04e-14    0.000307    0.00122     0.100       1(3.46e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 5.00  ======================
# 1           77.951            77.930      3.19e-10    1.07e-13    0.202       922         0.100       0(0.00402)
# 2           77.951            77.951      3.86e-10    1.25e-13    0.000338    -0.000114   0.100       1(3.56e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 5.10  ======================
# 1           75.700            75.680      6.91e-11    8.82e-15    0.205       924         0.100       0(0.00421)
# 2           75.701            75.701      3.11e-10    5.93e-14    0.00036     -0.00104    0.100       1(3.63e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 5.20  ======================
# 1           74.530            74.509      1.44e-10    5.34e-14    0.208       925         0.100       0(0.00434)
# 2           74.532            74.532      2.62e-10    1.52e-13    0.000375    -0.00161    0.100       1(3.66e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 5.30  ======================
# 1           72.927            72.911      3.66e-10    4.09e-13    0.157       927         0.100       0(0.00325)
# 2           72.930            72.930      6.61e-10    8.63e-13    0.000264    -0.00265    0.100       1(2.3e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 5.40  ======================
# 1           70.212            70.204      1.95e-10    6.5e-13     0.0846      930         0.100       0(0.0017)
# 2           70.214            70.214      3.06e-10    7.51e-13    0.000124    -0.00199    0.100       1(8.68e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 5.50  ======================
# 1           66.962            66.958      6.26e-10    1.85e-12    0.0456      933         0.100       1(0.000894)
# 2           66.963            66.963      6.24e-10    2.63e-12    6.03e-05    -0.000992   0.100       1(3.51e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 5.60  ======================
# 1           63.453            63.450      6.64e-10    2.75e-12    0.0247      937         0.100       1(0.000476)
# 2           63.453            63.453      3.97e-10    3.48e-13    3.01e-05    -0.000386   0.100       1(1.46e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 5.70  ======================
# 1           59.813            59.812      3.21e-10    1.69e-13    0.0134      940         0.100       1(0.000255)
# 2           59.813            59.813      4.08e-10    2.12e-12    1.55e-05    -0.000114   0.100       1(7.42e-08)
# SUCCEESS: virtual control and trust region < tol
# t curr: 5.80  ======================
# 1           56.105            56.104      2.2e-10     3.98e-13    0.00733     944         0.100       1(0.000137)
# 2           56.105            56.105      2.41e-10    5.78e-13    8.19e-06    -1.77e-05   0.100       1(4.13e-08)
# SUCCEESS: virtual control and trust region < tol
# t curr: 5.90  ======================
# 1           52.355            52.354      4.33e-11    1.02e-13    0.00403     948         0.100       1(7.4e-05)
# 2           52.355            52.355      4.33e-11    1.03e-13    4.47e-06    4.88e-06    0.100       1(2.37e-08)
# SUCCEESS: virtual control and trust region < tol
# t curr: 6.00  ======================
# 1           48.576            48.575      1.1e-10     3.96e-14    0.00223     951         0.100       1(3.99e-05)
# 2           48.576            48.576      1.1e-10     3.96e-14    2.51e-06    2.55e-06    0.100       1(1.34e-08)
# SUCCEESS: virtual control and trust region < tol
# t curr: 6.10  ======================
# 1           44.771            44.771      6.99e-11    6.27e-14    0.00125     955         0.100       1(2.14e-05)
# 2           44.771            44.771      7.4e-11     8.8e-14     1.46e-06    -4.85e-06   0.100       1(7.42e-09)
# SUCCEESS: virtual control and trust region < tol
# t curr: 6.20  ======================
# 1           40.939            40.939      1.63e-10    1.68e-13    0.000719    959         0.100       1(1.15e-05)
# SUCCEESS: virtual control and trust region < tol
# t curr: 6.30  ======================
# 1           37.076            37.076      1.17e-10    1.3e-13     0.000429    963         0.100       1(6.15e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 6.40  ======================
# 1           33.178            33.178      2.89e-10    6.36e-13    0.000268    967         0.100       1(3.29e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 6.50  ======================
# 1           29.249            29.249      1.15e-10    2.36e-14    0.00018     971         0.100       1(1.75e-06)
# SUCCEESS: virtual control and trust region < tol
# t curr: 6.60  ======================
# 1           25.320            25.320      1.63e-10    7.34e-14    0.000132    975         0.100       1(9.27e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 6.70  ======================
# 1           21.447            21.447      1.74e-10    1.87e-14    0.000105    979         0.100       1(4.88e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 6.80  ======================
# 1           17.708            17.708      1.25e-10    4.67e-14    8.74e-05    982         0.100       1(3.81e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 6.90  ======================
# 1           14.187            14.187      1.07e-10    2.86e-14    7.24e-05    986         0.100       1(3.53e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 7.00  ======================
# 1           10.976            10.976      1.21e-10    3.81e-14    5.61e-05    989         0.100       1(2.89e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 7.10  ======================
# 1           8.154             8.154       1.02e-10    3.57e-14    3.9e-05     992         0.100       1(2.06e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 7.20  ======================
# 1           5.755             5.755       4.65e-11    1.72e-15    2.4e-05     994         0.100       1(1.3e-07)
# SUCCEESS: virtual control and trust region < tol
# t curr: 7.30  ======================
# 1           3.688             3.688       2.16e-10    8.18e-14    1.36e-05    996         0.100       1(7.67e-08)
# SUCCEESS: virtual control and trust region < tol
# t curr: 7.40  ======================
# 1           2.185             2.185       1.18e-10    1.41e-14    7.46e-06    998         0.100       1(4.3e-08)
# SUCCEESS: virtual control and trust region < tol
# t curr: 7.50  ======================
# 1           1.385             1.385       5.01e-12    3.05e-15    3.99e-06    999         0.100       1(2.35e-08)
# SUCCEESS: virtual control and trust region < tol
# t curr: 7.60  ======================
# 1           0.959             0.959       3.57e-11    2.98e-15    2.1e-06     999         0.100       1(1.25e-08)
# SUCCEESS: virtual control and trust region < tol
# t curr: 7.70  ======================
# 1           0.732             0.732       8.39e-12    1.13e-15    1.1e-06     999         0.100       1(6.61e-09)
# SUCCEESS: virtual control and trust region < tol
# t curr: 7.80  ======================
# 1           0.612             0.612       1.24e-11    6.81e-15    5.74e-07    999         0.100       1(3.44e-09)
# SUCCEESS: virtual control and trust region < tol
# t curr: 7.90  ======================
# 1           0.547             0.547       1.99e-11    9.54e-14    2.99e-07    999         0.100       1(1.77e-09)
# SUCCEESS: virtual control and trust region < tol

# %%
plt.figure(figsize=(15,10))
fS = 18
plt.subplot(231)
plt.plot(xbar[:,0], xbar[:,1],'--', linewidth=2.0)
plt.plot(x_save[:,0], x_save[:,1],'-', linewidth=2.0)
plt.plot(xf[0],xf[1],"o",label='goal')
plt.gca().set_aspect('equal', adjustable='box')
plt.axis([-6, 6, -6, 6])
plt.xlabel('X (m)', fontsize = fS)
plt.ylabel('Y (m)', fontsize = fS)
plt.subplot(232)
plt.plot(t_index, xbar[:,0],'--', linewidth=2.0)
plt.plot(t_save, x_save[:,0],'-',linewidth=2.0)
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('x1 (m)', fontsize = fS)
plt.subplot(233)
plt.plot(t_index, xbar[:,1],'--',linewidth=2.0)
plt.plot(t_save, x_save[:,1],'-',linewidth=2.0)
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('x2 (m)', fontsize = fS)
plt.subplot(234)
plt.plot(t_index, np.rad2deg(xbar[:,2]),'--',linewidth=2.0)
plt.plot(t_save, np.rad2deg(x_save[:,2]),'-',linewidth=2.0)
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('x3 (rad)', fontsize = fS)
plt.subplot(235)
plt.plot(t_index, ubar[:,0],'--',linewidth=2.0)
plt.step(t_save,[*u_save[:,0],u_save[-1,0]],label='zoh',where='post')
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('v (m/s)', fontsize = fS)
plt.subplot(236)
plt.plot(t_index, np.rad2deg(ubar[:,1]),'--',linewidth=2.0)
plt.step(t_save,np.rad2deg([*u_save[:,1],u_save[-1,1]]),label='zoh',where='post')
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('w (rad/s)', fontsize = fS)
plt.show()

# %% [markdown]
# ## make a video

# %%
from matplotlib.patches import Rectangle,Ellipse
import imageio
import os

# %%
filenames = []
for idx in range(Nsim+1) :
    fig = plt.figure(figsize=(10,10))
    ax = fig.add_subplot(111)
    fS = 15
    plt.plot(xbar[:,0], xbar[:,1],'--', linewidth=2.0,label='nominal trajectory')
    plt.plot(x_save[:idx+1,0], x_save[:idx+1,1],'-', linewidth=2.0,label='result trajectory')
    if idx < Nsim :
        plt.plot(x_traj[idx][:,0], x_traj[idx][:,1],'-',color='tab:green', linewidth=2.0,label='future prediction')
        plt.plot(x_traj[idx][0,0], x_traj[idx][0,1],'o',color='tab:green', linewidth=2.0)
    for ce,H in zip(cobs,Hobs) :
        rx = 1/H[0,0]
        ry = 1/H[1,1]
        circle1 = Ellipse((ce[0],ce[1]),rx*2,ry*2,color='tab:red',alpha=0.03,fill=True)
        ax.add_patch(circle1)
    plt.gca().set_aspect('equal', adjustable='box')
    plt.axis([-6, 6, -6, 6])
    plt.xlabel('X (m)', fontsize = fS)
    plt.ylabel('Y (m)', fontsize = fS)
    plt.legend(fontsize=fS)

    filename = '../images/{:d}.png'.format(idx)
    plt.savefig(filename)
    filenames.append(filename)
    plt.close()

# %%
img_name = 'MPC_static_obstacle'
with imageio.get_writer('../images/'+img_name+'.gif', mode='I') as writer:
        for filename in filenames:
            image = imageio.imread(filename)
            writer.append_data(image)
for filename in set(filenames):
    os.remove(filename)
# Out:
# /var/folders/zh/8dk8mcb12vs7vp_rqg6sj_780000gn/T/ipykernel_15350/2391734039.py:4: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning dissapear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(filename)
