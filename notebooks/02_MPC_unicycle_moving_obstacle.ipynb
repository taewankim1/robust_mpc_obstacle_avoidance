# %%
import matplotlib.pyplot as plt
# %matplotlib inline  
# %load_ext autoreload
# %autoreload 2
import numpy as np
import time
import random
def print_np(x):
    print ("Type is %s" % (type(x)))
    print ("Shape is %s" % (x.shape,))
#     print ("Values are: \n%s" % (x))

# %%
import os
import sys
sys.path.append('../')

# %%
from model import UnicycleModel
from cost import FinaltimeFreeCost, UnicycleCost
from constraints import UnicycleConstraints
from PTR_tf_free import PTR_tf_free
from PTR_in_MPC import PTR_in_MPC
from Scaling import TrajectoryScaling

from scipy.interpolate import interp1d
from scipy.integrate import solve_ivp
# Out:
# (CVXPY) Dec 10 12:34:42 AM: Encountered unexpected exception importing solver SCS:
# ImportError("dlopen(/opt/anaconda3/envs/py309/lib/python3.9/site-packages/_scs_direct.cpython-39-darwin.so, 0x0002): Library not loaded: @rpath/liblapack.3.dylib\n  Referenced from: /opt/anaconda3/envs/py309/lib/python3.9/site-packages/_scs_direct.cpython-39-darwin.so\n  Reason: tried: '/opt/anaconda3/envs/py309/lib/python3.9/site-packages/../../liblapack.3.dylib' (no such file), '/opt/anaconda3/envs/py309/lib/python3.9/site-packages/../../liblapack.3.dylib' (no such file), '/opt/anaconda3/envs/py309/bin/../lib/liblapack.3.dylib' (no such file), '/opt/anaconda3/envs/py309/bin/../lib/liblapack.3.dylib' (no such file), '/usr/local/lib/liblapack.3.dylib' (no such file), '/usr/lib/liblapack.3.dylib' (no such file)")

# %% [markdown]
# ## Nominal trajectory generation

# %%
ix = 3
iu = 2
ih = 2
N = 50
tf = 10
delT = tf/N
max_iter = 30

# %%
myModel = UnicycleModel.unicycle('Hello',ix,iu,'numeric_central')
myCost = FinaltimeFreeCost.Finaltime('Hello',ix,iu,N)
myConst = UnicycleConstraints.UnicycleConstraints('Hello',ix,iu,[],[])

# %%
xi = np.zeros(3)
xi[0] = -5.0
xi[1] = -5.0 
xi[2] = 0

xf = np.zeros(3)
xf[0] = 5.0
xf[1] = 5.0
xf[2] = 0

x0 = np.zeros((N+1,ix))
for i in range(N+1) :
    x0[i] = (N-i)/N * xi + i/N * xf
    
u0 = np.zeros((N+1,iu))
ui = np.array([2,0])
uf = np.array([2,0])
for i in range(N+1) :
    u0[i] = (N-i)/N * ui + i/N * uf
    
x_max = np.array([5,5,np.deg2rad(90)])
x_min = np.zeros(ix)

u_max = np.array([2,np.deg2rad(90)]) 
u_min = np.array([0,0])


myScaling = TrajectoryScaling(x_min,x_max,u_min,u_max,tf)
Sx,iSx,sx,Su,iSu,su = myScaling.get_scaling()


TrajOpt = PTR_tf_free('unicycle',N,tf,max_iter,myModel,myCost,myConst,myScaling,
          type_discretization="foh",w_tf=1,w_vc=1e3,w_tr=1e-1,tol_vc=1e-6,tol_tr=1e-3)
# Out:
# Is DPP?  True

# %%
xfwd,ufwd,xnom,unom,tfnom,total_num_iter,l_all,l_tf,l_vc,l_tr,history_nom  = TrajOpt.run(x0,u0,xi,xf)
print("final time {:}".format(tfnom))
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2023-11-07
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │5.696      │5.000     │0        │0          │0           │1(-14.10)│0(6.958 )│0(0.128 )│
# │2     │7.734      │6.976     │0        │0          │0.597       │1(-14.06)│0(7.573 )│0(0.065 )│
# │3     │7.324      │7.132     │0        │0          │0.869       │1(-14.06)│0(1.919 )│0(0.015 )│
# │4     │7.256      │7.253     │0        │0          │0.983       │1(-14.23)│0(0.030 )│1(0.000 )│
# │5     │7.252      │7.251     │0        │0          │0.928       │1(-14.26)│0(0.010 )│1(0.000 )│
# │6     │7.251      │7.250     │0        │0          │0.473       │1(-14.30)│0(0.006 )│1(0.000 )│
# │7     │7.250      │7.250     │0        │0          │0.647       │1(-14.21)│0(0.002 )│1(0.000 )│
# │8     │7.250      │7.250     │0        │0          │0.596       │1(-14.21)│0(0.001 )│1(0.000 )│
# │9     │7.250      │7.250     │0        │0          │0.443       │1(-14.27)│1(0.001 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# final time 7.249560285243445

# %%
t_nom = np.array([i for i in range(N+1)]) / N * tfnom

# %%
plt.figure(figsize=(15,10))
fS = 18
plt.subplot(231)
plt.plot(xnom[:,0], xnom[:,1],'-', linewidth=2.0)
plt.plot(xf[0],xf[1],"o",label='goal')
plt.gca().set_aspect('equal', adjustable='box')
plt.axis([-6, 6, -6, 6])
plt.xlabel('X (m)', fontsize = fS)
plt.ylabel('Y (m)', fontsize = fS)
plt.subplot(232)
plt.plot(t_nom, xnom[:,0],'-', linewidth=2.0)
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('x (m)', fontsize = fS)
plt.subplot(233)
plt.plot(t_nom, xnom[:,1],'-',linewidth=2.0)
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('y (m)', fontsize = fS)
plt.subplot(234)
plt.plot(t_nom, np.rad2deg(xnom[:,2]),'-',linewidth=2.0)
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('$\Theta$ (deg)', fontsize = fS)
plt.subplot(235)
plt.plot(t_nom, unom[:,0],'-',linewidth=2.0)
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('v (m/s)', fontsize = fS)
plt.ylim([0,3])
plt.subplot(236)
plt.plot(t_nom, np.rad2deg(unom[:,1]),'-',linewidth=2.0)
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('w (deg/s)', fontsize = fS)
plt.show()

# %% [markdown]
# ## Set MPC controller with static obstacle

# %% [markdown]
# ### nominal trajectory is given as xbar, ubar

# %%
fun_unom = interp1d(t_nom,unom,axis=0)
def get_traj_teval(t_eval) :
    if len(t_eval) == 0 :
        return [],[]
    assert np.max(t_eval) <= t_nom[-1]
    def dfdt(t,x) :
        u = fun_unom(t)
        return np.squeeze(myModel.forward(x,u))

    sol = solve_ivp(dfdt,(t_nom[0],t_nom[-1]),xi,t_eval=t_eval,rtol=1e-12,atol=1e-12)
    return sol.y.T,fun_unom(t_eval)

def forward_dt(dt,xi,u) :
    def dfdt(t,x) :
        return np.squeeze(myModel.forward(x,u))
    sol = solve_ivp(dfdt,(0,dt),xi,rtol=1e-12,atol=1e-12)
    return sol
def get_H_obs(rx,ry) :
    return np.diag([1/rx,1/ry])

# %%
tbar = np.array([i for i in range(N+1)]) / N * tfnom
tfsim = 8
horizon = 2
dt = 0.1
Nsim = int(tfsim / dt)
Nmpc =  int(horizon / dt) # N+1 is total discretization points for state
print("Nmpc: {:}".format(Nmpc))

xi_mpc = np.zeros(3)
xi_mpc[0] = -5.0
xi_mpc[1] = -4.0 
xi_mpc[2] = 0
# Out:
# Nmpc: 20

# %%
# cost and constraint / model is identical
MPC_Cost = UnicycleCost.UnicycleMPCCost('Hello',ix,iu,Nmpc)
MPC_Const = UnicycleConstraints.UnicycleMPCConstraints('Hello',ix,iu,num_obs=1)

# # define optimal control
MPC_controller = PTR_in_MPC('unicycle',Nmpc,horizon,max_iter,myModel,MPC_Cost,MPC_Const,myScaling,
          type_discretization="zoh",w_c=1,w_vc=1e3,w_tr=1e-1,
                            tol_vc=1e-6,tol_tr=1e-3,verbosity=False)
# Out:
# Is DPP?  True

# %%
# moving obstacle
t_curr = 0
def fun_obstacle(t_eval) :
    t_eval = np.array(t_eval)
    N = len(t_eval)
    x = -0.5*t_eval + 2
    y = -10/8*t_eval + 5
    cobs = []
    Hobs = []
    H = get_H_obs(1,1) # fixed radius
    for i in range(N) :
        cobs.append([x[i],y[i]])
        Hobs.append(H)
    return cobs,Hobs

# %%
t_curr = 0
x_curr = np.copy(xi_mpc)

t_save,x_save,u_save = [],[],[]
t_save.append(t_curr)
x_save.append(xi_mpc)

t_traj,x_traj,u_traj = [],[],[]
c_traj,H_traj = [],[]

FRS_obstacle = 'proactive' 

for _ in range(Nsim) : # Nsim
    print("t curr: {:.2f}  ======================".format(t_curr))
    # estimating nominal trajectory within horizon
    t_horizon = np.array([t_curr + dt*i for i in range(Nmpc+1)])
    t_eval = t_horizon[t_horizon <= tfnom]
    t_end = t_horizon[t_horizon > tfnom]
    xfwd,ufwd = get_traj_teval(t_eval)
    for _ in t_end :
        if len(xfwd) == 0 :
            xfwd = xnom[-1]
            ufwd = unom[-1]
        else :
            xfwd = np.vstack((xfwd,xnom[-1]))
            ufwd = np.vstack((ufwd,unom[-1]))
    
    # obstacle forward model
    cmpc,Hmpc = [],[]
    if FRS_obstacle == 'reactive' :
        ctmp,Htmp = fun_obstacle([t_curr])
        c = ctmp[0]
        H = Htmp[0]
        for i in range(Nmpc+1) :
            cmpc.append(c)
            Hmpc.append(H)   
    elif FRS_obstacle == 'proactive' :
        cmpc,Hmpc = fun_obstacle(t_horizon)
    
    # solve optimal control
    # initiall condition
    if t_curr == 0 :
        x0 = xfwd
        u0 = ufwd
    else :
        x0 = np.copy(xmpc)
        x0[:Nmpc] = xmpc[1:]
        u0 = np.copy(umpc)
        u0[:Nmpc] = umpc[1:]


    _,_,xmpc,umpc,tfmpc,_,l_all,l_c,l_vc,l_tr,history_mpc  = MPC_controller.run(x0,u0,x_curr,xfwd,ufwd,cmpc,Hmpc)

    # apply input to the system (integration)
    sol = forward_dt(dt,x_curr,umpc[0])
    t_curr += dt
    x_curr = sol.y.T[-1]

    # save
    t_save.append(t_curr)
    x_save.append(x_curr)
    u_save.append(umpc[0])

    t_traj.append(t_horizon)
    x_traj.append(xmpc)
    u_traj.append(umpc)
    c_traj.append(cmpc)
    H_traj.append(Hmpc)
#     break

x_save = np.array(x_save)
u_save = np.array(u_save)
# Out:
# t curr: 0.00  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │124.495    │2.000     │124      │0          │0           │1(-11.26)│0(6.119 )│0(0.030 )│
# │2     │134.024    │2.000     │134      │0          │0.981       │1(-10.75)│0(0.354 )│0(0.001 )│
# │3     │133.855    │2.000     │134      │0          │0.769       │1(-11.27)│0(0.060 )│1(0.000 )│
# │4     │133.880    │2.000     │134      │0          │0.923       │1(-11.30)│0(0.004 )│1(0.000 )│
# │5     │133.883    │2.000     │134      │0          │0.924       │1(-11.27)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 0.10  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │122.448    │2.000     │122      │0          │0           │1(-11.28)│0(0.147 )│1(0.000 )│
# │2     │122.434    │2.000     │122      │0          │0.989       │1(-11.29)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 0.20  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │111.028    │2.000     │111      │0          │0           │1(-11.30)│0(0.149 )│1(0.000 )│
# │2     │111.013    │2.000     │111      │0          │0.99        │1(-11.30)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 0.30  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │100.486    │2.000     │100      │0          │0           │1(-11.27)│0(0.150 )│1(0.000 )│
# │2     │100.471    │2.000     │100      │0          │0.99        │1(-11.27)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 0.40  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │91.406     │2.000     │91.4     │0          │0           │1(-11.29)│0(0.151 )│1(0.000 )│
# │2     │91.391     │2.000     │91.4     │0          │0.991       │1(-11.29)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 0.50  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │84.216     │2.000     │84.2     │0          │0           │1(-11.24)│0(0.152 )│1(0.000 )│
# │2     │84.201     │2.000     │84.2     │0          │0.991       │1(-11.24)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 0.60  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │78.608     │2.000     │78.6     │0          │0           │1(-11.41)│0(0.153 )│1(0.000 )│
# │2     │78.592     │2.000     │78.6     │0          │0.991       │1(-11.41)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 0.70  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │74.258     │2.000     │74.2     │0          │0           │1(-11.57)│0(0.153 )│1(0.000 )│
# │2     │74.242     │2.000     │74.2     │0          │0.992       │1(-11.57)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 0.80  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │71.093     │2.000     │71.1     │0          │0           │1(-10.73)│0(0.153 )│1(0.000 )│
# │2     │71.078     │2.000     │71.1     │0          │0.992       │1(-10.73)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 0.90  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │69.085     │2.000     │69.1     │0          │0           │1(-10.76)│0(0.154 )│1(0.000 )│
# │2     │69.070     │2.000     │69.1     │0          │0.993       │1(-10.77)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 1.00  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │67.970     │2.000     │68       │0          │0           │1(-10.74)│0(0.154 )│1(0.000 )│
# │2     │67.954     │2.000     │68       │0          │0.993       │1(-10.74)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 1.10  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │67.474     │2.000     │67.5     │0          │0           │1(-10.77)│0(0.154 )│1(0.000 )│
# │2     │67.459     │2.000     │67.5     │0          │0.994       │1(-10.77)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 1.20  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │67.371     │2.000     │67.4     │0          │0           │1(-10.74)│0(0.154 )│1(0.000 )│
# │2     │67.355     │2.000     │67.4     │0          │0.994       │1(-10.73)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 1.30  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │67.488     │2.000     │67.5     │0          │0           │1(-11.52)│0(0.154 )│1(0.000 )│
# │2     │67.473     │2.000     │67.5     │0          │0.995       │1(-11.52)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 1.40  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │67.711     │2.000     │67.7     │0          │0           │1(-11.46)│0(0.154 )│1(0.000 )│
# │2     │67.696     │2.000     │67.7     │0          │0.995       │1(-11.45)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 1.50  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │67.968     │2.000     │68       │0          │0           │1(-11.41)│0(0.154 )│1(0.000 )│
# │2     │67.953     │2.000     │68       │0          │0.995       │1(-11.41)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 1.60  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │68.218     │2.000     │68.2     │0          │0           │1(-11.24)│0(0.154 )│1(0.000 )│
# │2     │68.203     │2.000     │68.2     │0          │0.995       │1(-11.24)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 1.70  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │70.176     │2.000     │70.2     │0          │0           │1(-11.18)│0(0.001 )│1(0.000 )│
# │2     │70.176     │2.000     │70.2     │0          │1           │1(-11.11)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 1.80  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │81.251     │2.000     │81.2     │0          │0           │1(-11.13)│0(0.070 )│1(0.000 )│
# │2     │81.247     │2.000     │81.2     │0          │0.997       │1(-11.03)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 1.90  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │105.327    │2.000     │105      │0          │0           │1(-11.18)│0(0.062 )│1(0.000 )│
# │2     │105.319    │2.000     │105      │0          │0.985       │1(-10.97)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 2.00  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │145.859    │2.000     │146      │0          │0           │1(-10.96)│0(0.069 )│1(0.000 )│
# │2     │145.832    │2.000     │146      │0          │0.98        │1(-10.93)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 2.10  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │205.895    │2.000     │206      │0          │0           │1(-10.80)│0(0.074 )│1(0.000 )│
# │2     │205.806    │2.000     │206      │0          │0.972       │1(-10.78)│0(0.002 )│1(0.000 )│
# │3     │205.784    │2.000     │206      │0          │0.825       │1(-10.78)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 2.20  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │287.481    │2.000     │287      │0          │0           │1(-10.76)│0(0.089 )│1(0.001 )│
# │2     │287.222    │2.000     │287      │0          │0.936       │1(-10.74)│0(0.011 )│1(0.000 )│
# │3     │287.098    │2.000     │287      │0          │0.747       │1(-10.75)│0(0.003 )│1(0.000 )│
# │4     │287.036    │2.000     │287      │0          │0.623       │1(-10.75)│0(0.001 )│1(0.000 )│
# │5     │287.004    │2.000     │287      │0          │0.63        │1(-10.75)│1(0.001 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 2.30  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │389.534    │2.000     │390      │0          │0           │1(-10.93)│0(0.219 )│0(0.001 )│
# │2     │388.142    │2.000     │388      │0          │0.709       │1(-10.73)│0(0.070 )│1(0.000 )│
# │3     │386.464    │2.000     │386      │0          │0.436       │1(-11.42)│0(0.048 )│1(0.000 )│
# │4     │384.220    │2.000     │384      │0          │0.161       │1(-11.36)│0(0.074 )│1(0.001 )│
# │5     │380.575    │2.000     │381      │0          │0.118       │1(-11.41)│0(0.114 )│0(0.001 )│
# │6     │373.128    │2.000     │373      │0          │0.0285      │1(-11.09)│0(0.235 )│0(0.002 )│
# │7     │353.394    │2.000     │353      │0          │0.121       │1(-11.37)│0(0.565 )│0(0.006 )│
# │8     │306.889    │2.000     │307      │0          │0.648       │1(-10.97)│0(0.916 )│0(0.007 )│
# │9     │266.372    │2.000     │266      │0          │0.25        │1(-11.20)│0(2.313 )│0(0.009 )│
# │10    │237.082    │2.000     │237      │0          │0.313       │1(-11.25)│0(2.344 )│0(0.008 )│
# │11    │227.054    │2.000     │227      │0          │0.94        │1(-11.40)│0(0.688 )│1(0.001 )│
# │12    │226.202    │2.000     │226      │0          │0.927       │1(-11.30)│0(0.064 )│1(0.000 )│
# │13    │225.611    │2.000     │226      │0          │0.623       │1(-11.40)│0(0.018 )│1(0.000 )│
# │14    │225.589    │2.000     │226      │0          │0.707       │1(-11.37)│0(0.002 )│1(0.000 )│
# │15    │225.589    │2.000     │226      │0          │0.578       │1(-11.36)│1(0.001 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 2.40  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │238.483    │2.000     │238      │0          │0           │1(-11.32)│0(0.299 )│0(0.002 )│
# │2     │237.804    │2.000     │238      │0          │0.903       │1(-11.34)│0(0.032 )│1(0.000 )│
# │3     │237.669    │2.000     │238      │0          │0.779       │1(-11.32)│0(0.007 )│1(0.000 )│
# │4     │237.633    │2.000     │238      │0          │0.811       │1(-11.32)│0(0.002 )│1(0.000 )│
# │5     │237.623    │2.000     │238      │0          │0.695       │1(-11.32)│1(0.001 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 2.50  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │247.502    │2.000     │247      │0          │0           │1(-11.25)│0(0.289 )│0(0.001 )│
# │2     │246.943    │2.000     │247      │0          │0.891       │1(-11.28)│0(0.024 )│1(0.000 )│
# │3     │246.852    │2.000     │247      │0          │0.847       │1(-11.27)│0(0.004 )│1(0.000 )│
# │4     │246.829    │2.000     │247      │0          │0.736       │1(-11.27)│1(0.001 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 2.60  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │253.773    │2.000     │254      │0          │0           │1(-11.16)│0(0.269 )│1(0.001 )│
# │2     │253.348    │2.000     │253      │0          │0.896       │1(-11.16)│0(0.017 )│1(0.000 )│
# │3     │253.289    │2.000     │253      │0          │0.858       │1(-11.16)│0(0.003 )│1(0.000 )│
# │4     │253.277    │2.000     │253      │0          │0.815       │1(-11.16)│1(0.001 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 2.70  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │257.657    │2.000     │258      │0          │0           │1(-11.10)│0(0.238 )│1(0.001 )│
# │2     │257.403    │2.000     │257      │0          │0.907       │1(-11.11)│0(0.011 )│1(0.000 )│
# │3     │257.377    │2.000     │257      │0          │0.891       │1(-11.09)│0(0.002 )│1(0.000 )│
# │4     │257.372    │2.000     │257      │0          │0.772       │1(-11.09)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 2.80  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │259.483    │2.000     │259      │0          │0           │1(-11.02)│0(0.213 )│0(0.001 )│
# │2     │259.307    │2.000     │259      │0          │0.927       │1(-10.98)│0(0.007 )│1(0.000 )│
# │3     │259.294    │2.000     │259      │0          │0.903       │1(-10.98)│0(0.001 )│1(0.000 )│
# │4     │259.292    │2.000     │259      │0          │0.787       │1(-10.98)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 2.90  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │259.174    │2.000     │259      │0          │0           │1(-10.90)│0(0.191 )│0(0.001 )│
# │2     │259.058    │2.000     │259      │0          │0.948       │1(-10.94)│0(0.004 )│1(0.000 )│
# │3     │259.053    │2.000     │259      │0          │0.916       │1(-11.02)│1(0.001 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 3.00  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │256.635    │2.000     │257      │0          │0           │1(-10.98)│0(0.174 )│0(0.001 )│
# │2     │256.558    │2.000     │257      │0          │0.964       │1(-10.97)│0(0.002 )│1(0.000 )│
# │3     │256.556    │2.000     │257      │0          │0.937       │1(-11.01)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 3.10  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │251.604    │2.000     │252      │0          │0           │1(-10.99)│0(0.163 )│0(0.001 )│
# │2     │251.555    │2.000     │252      │0          │0.975       │1(-10.97)│0(0.001 )│1(0.000 )│
# │3     │251.555    │2.000     │252      │0          │0.951       │1(-11.04)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 3.20  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │243.785    │2.000     │244      │0          │0           │1(-10.93)│0(0.156 )│0(0.001 )│
# │2     │243.753    │2.000     │244      │0          │0.979       │1(-10.94)│1(0.001 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 3.30  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │233.042    │2.000     │233      │0          │0           │1(-11.05)│0(0.153 )│0(0.001 )│
# │2     │233.019    │2.000     │233      │0          │0.982       │1(-11.05)│1(0.001 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 3.40  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │219.952    │2.000     │220      │0          │0           │1(-10.99)│0(0.151 )│1(0.001 )│
# │2     │219.935    │2.000     │220      │0          │0.985       │1(-10.99)│1(0.001 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 3.50  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │207.482    │2.000     │207      │0          │0           │1(-11.03)│0(0.150 )│1(0.001 )│
# │2     │207.467    │2.000     │207      │0          │0.987       │1(-11.07)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 3.60  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │196.270    │2.000     │196      │0          │0           │1(-11.02)│0(0.150 )│1(0.001 )│
# │2     │196.256    │2.000     │196      │0          │0.988       │1(-11.15)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 3.70  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │186.772    │2.000     │187      │0          │0           │1(-11.31)│0(0.150 )│1(0.001 )│
# │2     │186.758    │2.000     │187      │0          │0.989       │1(-11.18)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 3.80  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │178.293    │2.000     │178      │0          │0           │1(-10.86)│0(0.151 )│1(0.001 )│
# │2     │178.279    │2.000     │178      │0          │0.99        │1(-10.87)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 3.90  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │160.613    │2.000     │161      │0          │0           │1(-10.81)│0(0.151 )│1(0.001 )│
# │2     │160.598    │2.000     │161      │0          │0.991       │1(-10.85)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 4.00  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# ...
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │33.051     │2.000     │33.1     │0          │0           │1(-11.56)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 6.50  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │29.106     │2.000     │29.1     │0          │0           │1(-11.51)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 6.60  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │25.177     │2.000     │25.2     │0          │0           │1(-11.50)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 6.70  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │21.318     │2.000     │21.3     │0          │0           │1(-11.47)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 6.80  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │17.600     │2.000     │17.6     │0          │0           │1(-11.16)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 6.90  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │14.100     │2.000     │14.1     │0          │0           │1(-10.98)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 7.00  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │10.906     │2.000     │10.9     │0          │0           │1(-11.81)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 7.10  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │8.094      │2.000     │8.09     │0          │0           │1(-11.63)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 7.20  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │5.699      │2.000     │5.7      │0          │0           │1(-11.70)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 7.30  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │3.627      │2.000     │3.63     │0          │0           │1(-11.64)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 7.40  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │2.119      │2.000     │2.12     │0          │0           │1(-12.38)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 7.50  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │1.316      │2.000     │1.32     │0          │0           │1(-12.52)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 7.60  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │0.888      │2.000     │0.888    │0          │0           │1(-12.44)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 7.70  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │0.661      │2.000     │0.661    │0          │0           │1(-12.16)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 7.80  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │0.540      │2.000     │0.54     │0          │0           │1(-12.33)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘
#
# t curr: 7.90  ======================
# ┌──────────────────────────────────────────────────────────────────────────────────────────────┐
#
# │                          ..:: Aircraft Landing by SCP ::..                                   │
#
# ├──────┬───────────┬──────────┬─────────┬───────────┬────────────┬─────────┬─────────┬─────────┤
#
# │ iter │  total    │ final    │ thrust  │ control   │ reduction  │ vc      │ tr      │ dyn     │
#
# │      │  cost     │ time [s] │ energy  │ rate      │ ratio      │ (log10) │         │         │
#
# ├──────┼───────────┼──────────┼─────────┼───────────┼────────────┼─────────┼─────────┼─────────┤
#
# │1     │0.476      │2.000     │0.476    │0          │0           │1(-12.03)│1(0.000 )│1(0.000 )│
# ├──────┴───────────┴──────────┴─────────┴───────────┴────────────┴─────────┴─────────┴─────────┤
#
# │                SUCCEESS: virtual control and trust region < tol                              │
#
# └──────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
plt.figure(figsize=(15,10))
fS = 18
plt.subplot(231)
plt.plot(xnom[:,0], xnom[:,1],'--', linewidth=2.0)
plt.plot(x_save[:,0], x_save[:,1],'-', linewidth=2.0)
plt.plot(xf[0],xf[1],"o",label='goal')
plt.gca().set_aspect('equal', adjustable='box')
plt.axis([-6, 6, -6, 6])
plt.xlabel('X (m)', fontsize = fS)
plt.ylabel('Y (m)', fontsize = fS)
plt.subplot(232)
plt.plot(t_nom, xnom[:,0],'--', linewidth=2.0)
plt.plot(t_save, x_save[:,0],'-',linewidth=2.0)
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('x1 (m)', fontsize = fS)
plt.subplot(233)
plt.plot(t_nom, xnom[:,1],'--',linewidth=2.0)
plt.plot(t_save, x_save[:,1],'-',linewidth=2.0)
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('x2 (m)', fontsize = fS)
plt.subplot(234)
plt.plot(t_nom, np.rad2deg(xnom[:,2]),'--',linewidth=2.0)
plt.plot(t_save, np.rad2deg(x_save[:,2]),'-',linewidth=2.0)
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('x3 (rad)', fontsize = fS)
plt.subplot(235)
plt.plot(t_nom, unom[:,0],'--',linewidth=2.0)
plt.step(t_save,[*u_save[:,0],u_save[-1,0]],label='zoh',where='post')
plt.plot(t_save, np.array(t_save)*0+MPC_Const.vmax,'--',linewidth=2.0,color='tab:red')
plt.plot(t_save, np.array(t_save)*0+MPC_Const.vmin,'--',linewidth=2.0,color='tab:red')
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('v (m/s)', fontsize = fS)
plt.subplot(236)
plt.plot(t_nom, np.rad2deg(unom[:,1]),'--',linewidth=2.0)
plt.step(t_save,np.rad2deg([*u_save[:,1],u_save[-1,1]]),label='zoh',where='post')
plt.plot(t_save, np.array(t_save)*0+np.rad2deg(MPC_Const.wmax),'--',linewidth=2.0,color='tab:red')
plt.plot(t_save, np.array(t_save)*0+np.rad2deg(MPC_Const.wmin),'--',linewidth=2.0,color='tab:red')
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('w (rad/s)', fontsize = fS)
plt.show()

# %% [markdown]
# ## make a video

# %%
from matplotlib.patches import Rectangle,Ellipse
import imageio.v2 as imageio
import os

# %%
filenames = []
t_curr = 0
for idx in range(Nsim+1) :
    fig = plt.figure(figsize=(10,10))
    ax = fig.add_subplot(111)
    fS = 15
    plt.plot(xnom[:,0], xnom[:,1],'--', linewidth=2.0,label='nominal trajectory')
    plt.plot(x_save[:idx+1,0], x_save[:idx+1,1],'-', linewidth=2.0,label='result trajectory')
    if idx < Nsim :
        plt.plot(x_traj[idx][:,0], x_traj[idx][:,1],'-',color='tab:green', linewidth=2.0,label='future prediction')
        plt.plot(x_traj[idx][0,0], x_traj[idx][0,1],'o',color='tab:green', linewidth=2.0)
#     for ce,H in zip(cobs,Hobs) :
    if idx < Nsim :
        cmpc = c_traj[idx]
        Hmpc = H_traj[idx]
    for idx_obstacle, (ce,H) in enumerate(zip(cmpc,Hmpc)) :
        rx = 1/H[0,0]
        ry = 1/H[1,1]
        if idx_obstacle == 0:
            circle1 = Ellipse((ce[0],ce[1]),rx*2,ry*2,color='tab:red',alpha=1.0,fill=True)
        else :
            circle1 = Ellipse((ce[0],ce[1]),rx*2,ry*2,color='tab:pink',alpha=0.2*np.exp(-idx_obstacle/10),fill=True)
        ax.add_patch(circle1)
    
    plt.gca().set_aspect('equal', adjustable='box')
    plt.axis([-6, 6, -6, 6])
    plt.xlabel('X (m)', fontsize = fS)
    plt.ylabel('Y (m)', fontsize = fS)
    plt.legend(fontsize=fS)

    filename = '../images/{:d}.png'.format(idx)
    plt.savefig(filename)
    filenames.append(filename)
    plt.close()
    t_curr += dt

# %%
img_name = 'MPC_moving_obstacle_' + FRS_obstacle
with imageio.get_writer('../images/'+img_name+'.gif', mode='I') as writer:
        for filename in filenames:
            image = imageio.imread(filename)
            writer.append_data(image)

# %%
img_name = 'video_MPC_moving_obstacle_' + FRS_obstacle
with imageio.get_writer('../images/'+img_name+'.mov', fps=int(1/dt)) as writer:
    for filename in filenames:
        image = imageio.imread(filename)
        writer.append_data(image)

# %%
for filename in set(filenames):
    os.remove(filename)

# %%
filenames = []
t_curr = 0
# for idx in range(Nsim+1) :
idx = 0
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
fS = 15
plt.plot(xnom[:,0], xnom[:,1],'--', linewidth=2.0,label='nominal trajectory')
plt.plot(x_save[:idx+1,0], x_save[:idx+1,1],'-', linewidth=2.0,label='result trajectory')
if idx < Nsim :
    plt.plot(x_traj[idx][:,0], x_traj[idx][:,1],'-',color='tab:green', linewidth=2.0,label='future prediction')
    plt.plot(x_traj[idx][0,0], x_traj[idx][0,1],'o',color='tab:green', linewidth=2.0)
#     for ce,H in zip(cobs,Hobs) :
if idx < Nsim :
    cmpc = c_traj[idx]
    Hmpc = H_traj[idx]
for idx_obstacle, (ce,H) in enumerate(zip(cmpc,Hmpc)) :
    rx = 1/H[0,0]
    ry = 1/H[1,1]
    if idx_obstacle == 0:
        circle1 = Ellipse((ce[0],ce[1]),rx*2,ry*2,color='tab:red',alpha=1.0,fill=True)
    else :
        circle1 = Ellipse((ce[0],ce[1]),rx*2,ry*2,color='tab:pink',alpha=0.2*np.exp(-idx_obstacle/10),fill=True)
    ax.add_patch(circle1)

plt.gca().set_aspect('equal', adjustable='box')
plt.axis([-6, 6, -6, 6])
plt.xlabel('X (m)', fontsize = fS)
plt.ylabel('Y (m)', fontsize = fS)
plt.legend(fontsize=fS)
